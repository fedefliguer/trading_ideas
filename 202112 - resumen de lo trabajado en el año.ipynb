# %% [markdown]
# ## Instalación librerías

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading https://files.pythonhosted.org/packages/a7/ee/315752b9ef281ba83c62aa7ec2e2074f85223da6e7e74efb4d3e11c0f510/yfinance-0.1.59.tar.gz
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.9)
# Collecting lxml>=4.5.1
#   Downloading https://files.pythonhosted.org/packages/30/c0/d0526314971fc661b083ab135747dc68446a3022686da8c16d25fcf6ef07/lxml-4.6.3-cp37-cp37m-manylinux2014_x86_64.whl (6.3MB)
#      |████████████████████████████████| 6.3MB 26.2MB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Building wheels for collected packages: yfinance
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.59-py2.py3-none-any.whl size=23442 sha256=b6e8fab6ec061b8c75b54c71d5ae871aa2a8d0d4f14a9022705446d6d083cd45
#   Stored in directory: /root/.cache/pip/wheels/f8/2a/0f/4b5a86e1d52e451757eb6bc17fd899629f0925c777741b6d04
# Successfully built yfinance
# Installing collected packages: lxml, yfinance
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# Successfully installed lxml-4.6.3 yfinance-0.1.59

# %% [markdown]
# ## Detalle de funciones

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
pd.options.mode.chained_assignment = None
from datetime import date
from datetime import timedelta 
import matplotlib.pyplot as plt
import scipy.stats as st
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.metrics import fbeta_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
pd.set_option('display.max_columns', 400)
pd.set_option('display.max_rows', 5000)
pd.set_option('display.width', 1000)

# %%
def descarga(ticker, fc_empieza, fc_termina):
  base = yf.download(ticker, start=fc_empieza, end=fc_termina)
  base = base[['Close', 'Volume', 'High', 'Low']]
  base.insert(loc=0, column='Ticker', value=ticker)
  base.reset_index(level=0, inplace=True)
  base.columns=['fc', 'ticker', 'y', 'vl', 'high', 'low']
  return base

# %%
def calcula_pc_merval(dataset):
  dataset = pd.merge(dataset,mvl,on='fc',how='left')
  dataset['pc_merval'] = dataset.y/dataset.mvl
  dataset = dataset.drop(['mvl'], axis=1)
  return dataset

# %%
def calcula_amplitud(dataset):
  dataset['amplitud'] = (dataset.high - dataset.low)/dataset.y
  return dataset

# %%
def estandariza_volumen(dataset):
  mean_vl = dataset['vl'].mean()
  std_vl = dataset['vl'].std()
  dataset['vl'] = (dataset.vl - mean_vl)/std_vl
  return dataset

# %%
def calcula_medias(dataset):
  period = 12
  sma = dataset['y'].rolling(period, min_periods=period).mean()
  idx_start = sma.isna().sum() + 1 - period
  idx_end = idx_start + period
  sma = sma[idx_start: idx_end]
  rest = dataset['y'][idx_end:]
  ema = pd.concat([sma, rest]).ewm(span=period, adjust=False).mean()
  dataset['exp1'] = ema
  period = 26
  sma = dataset['y'].rolling(period, min_periods=period).mean()
  idx_start = sma.isna().sum() + 1 - period
  idx_end = idx_start + period
  sma = sma[idx_start: idx_end]
  rest = dataset['y'][idx_end:]
  ema = pd.concat([sma, rest]).ewm(span=period, adjust=False).mean()
  dataset['exp2'] = ema
  macd = dataset['exp1']-dataset['exp2']
  dataset['macd'] = macd
  dataset['exp3'] = macd.ewm(span=9, adjust=False).mean()
  dataset['histog'] = dataset['macd'] - dataset['exp3'] 
  return dataset

# %%
def calcula_historia(dataset, lags):
  for (columnName, columnData) in dataset.iloc[:,6:].iteritems():
    i = 1
    while i < lags:
      colname = "var_%s_%s" % (columnName, i)
      dataset[colname] = columnData/columnData.shift(i)-1
      i = i + 1
  return dataset

# %%
def calcula_canalidad_y(dataset):
  i = 1
  dataset['lag_y_1'] = dataset.y.shift(1)
  dataset['nu_dias_y_entre_max_min_30'] = np.where((dataset['lag_y_1'] < dataset['high']) & (dataset['lag_y_1'] > dataset['low']), 1, 0)
  dataset['nu_dias_y_entre_5pc_30'] = np.where((dataset['lag_y_1'] < (dataset.y * 1.05)) & (dataset['lag_y_1'] > (dataset.y * 0.95)), 1, 0)

  dataset['nu_dias_y_entre_max_min_90'] = np.where((dataset['lag_y_1'] < dataset['high']) & (dataset['lag_y_1'] > dataset['low']), 1, 0)
  dataset['nu_dias_y_entre_5pc_90'] = np.where((dataset['lag_y_1'] < (dataset.y * 1.05)) & (dataset['lag_y_1'] > (dataset.y * 0.95)), 1, 0)

  dataset['nu_dias_y_entre_max_min_180'] = np.where((dataset['lag_y_1'] < dataset['high']) & (dataset['lag_y_1'] > dataset['low']), 1, 0)
  dataset['nu_dias_y_entre_5pc_180'] = np.where((dataset['lag_y_1'] < (dataset.y * 1.05)) & (dataset['lag_y_1'] > (dataset.y * 0.95)), 1, 0)

  dataset = dataset.drop(['lag_y_1'], axis=1)
  i = 2
  while i < 30:
    colname = "lag_y_%s" % (i)
    dataset[colname] = dataset.y.shift(i)
    dataset['nu_dias_y_entre_max_min_30'] = dataset['nu_dias_y_entre_max_min_30'] + np.where((dataset[colname] < dataset['high']) & (dataset[colname] > dataset['low']), 1, 0)
    dataset['nu_dias_y_entre_5pc_30'] = dataset['nu_dias_y_entre_5pc_30'] + np.where((dataset[colname] < (dataset.y * 1.05)) & (dataset[colname] > (dataset.y * 0.95)), 1, 0)
    i = i + 1
    dataset = dataset.drop([colname], axis=1)

  i = 2
  while i < 90:
    colname = "lag_y_%s" % (i)
    dataset[colname] = dataset.y.shift(i)
    dataset['nu_dias_y_entre_max_min_90'] = dataset['nu_dias_y_entre_max_min_90'] + np.where((dataset[colname] < dataset['high']) & (dataset[colname] > dataset['low']), 1, 0)
    dataset['nu_dias_y_entre_5pc_90'] = dataset['nu_dias_y_entre_5pc_90'] + np.where((dataset[colname] < (dataset.y * 1.05)) & (dataset[colname] > (dataset.y * 0.95)), 1, 0)
    i = i + 1
    dataset = dataset.drop([colname], axis=1)

  i = 2
  while i < 180:
    colname = "lag_y_%s" % (i)
    dataset[colname] = dataset.y.shift(i)
    dataset['nu_dias_y_entre_max_min_180'] = dataset['nu_dias_y_entre_max_min_180'] + np.where((dataset[colname] < dataset['high']) & (dataset[colname] > dataset['low']), 1, 0)
    dataset['nu_dias_y_entre_5pc_180'] = dataset['nu_dias_y_entre_5pc_180'] + np.where((dataset[colname] < (dataset.y * 1.05)) & (dataset[colname] > (dataset.y * 0.95)), 1, 0)
    i = i + 1
    dataset = dataset.drop([colname], axis=1)

  return dataset

# %%
def calcula_canalidad_histog_macd(dataset):
  list = [5, 30, 90, 180]
  for ventana in list:
    i = 1
    dataset['lag_histog_1'] = dataset.histog.shift(1)
    colname_nu_1 = "nu_dias_histog_entre_5pc_%s" % (ventana)
    dataset[colname_nu_1] = np.where((dataset['lag_histog_1'] < (dataset.histog * 1.05)) & (dataset['lag_histog_1'] > (dataset.histog * 0.95)), 1, 0)

    colname_nu_2 = "nu_dias_histog_positivo_%s" % (ventana)
    dataset[colname_nu_2] = np.where((dataset['lag_histog_1']>0), 1, 0)

    colname_nu_3 = "nu_dias_histog_negativo_%s" % (ventana)
    dataset[colname_nu_3] = np.where((dataset['lag_histog_1']<0), 1, 0)

    colname_nu_4 = "nu_dias_histog_mismo_signo_%s" % (ventana)
    dataset[colname_nu_4] = np.where(((dataset['lag_histog_1']>0) & (dataset['histog']>0))|((dataset['lag_histog_1']<0) & (dataset['histog']<0)), 1, 0)

    dataset = dataset.drop(['lag_histog_1'], axis=1)
    i = 2
    while i < (ventana+1):
      colname = "lag_histog_%s" % (i)
      dataset[colname] = dataset.histog.shift(i)
      dataset[colname_nu_1] = dataset[colname_nu_1] + np.where((dataset[colname] < (dataset.histog * 1.50)) & (dataset[colname] > (dataset.histog * 0.50)), 1, 0)
      dataset[colname_nu_2] = dataset[colname_nu_2] + np.where((dataset[colname]>0), 1, 0)
      dataset[colname_nu_3] = dataset[colname_nu_3] + np.where((dataset[colname]<0), 1, 0)
      dataset[colname_nu_4] = dataset[colname_nu_4] + np.where(((dataset[colname]>0) & (dataset['histog']>0))|((dataset[colname]<0) & (dataset['histog']<0)), 1, 0)
      i = i + 1
      dataset = dataset.drop([colname], axis=1)
  return dataset

# %%
def calcula_AT_tendencias(dataset, lags):
  
  # Construye las columnas para determinar si es un pico
  i = 1
  while i < (lags+1):
      colname = 'p%sb' % (i)                                                  
      dataset[colname] = round(dataset.y.shift(i),2)
      j = i * -1
      colname = 'p%sf' % (-j)                                                  
      dataset[colname] = round(dataset.y.shift(j),2)
      i = i + 1

  # Determina si es un pico  
  dataset['maxb'] = round(dataset.filter(regex=(".*b")).max(axis=1),2)
  dataset['maxf']= round(dataset.filter(regex=(".*f")).max(axis=1),2)
  dataset['minb'] = round(dataset.filter(regex=(".*b")).min(axis=1),2)
  dataset['minf'] = round(dataset.filter(regex=(".*f")).min(axis=1),2)
  dataset['T'] = np.where((dataset['y']>dataset['maxb']) & (dataset['y']>dataset['maxf']), 1, 0)
  dataset['P'] = np.where((dataset['y']<dataset['minb']) & (dataset['y']<dataset['minf']), 1, 0)

  techos = dataset[(dataset['T']==1)]
  techos['m'] = (techos.y.shift(1) - techos.y)/(techos.fc.shift(1) - techos.fc).dt.days
  techos.name = 'techos'
  pisos = dataset[(dataset['P']==1)]
  pisos['m'] = (pisos.y.shift(1) - pisos.y)/(pisos.fc.shift(1) - pisos.fc).dt.days
  pisos.name = 'pisos'
  dataset_list = [techos, pisos]

  for dataset_picos in dataset_list:  # En cada dataset (techos y pisos)
    name = dataset_picos.name
    dias = len(dataset)
    for index, row in dataset_picos.iloc[1:].iterrows(): # Para cada pico detectado (fila del dataset) a partir del segundo (porque el primero no tiene anterior, no tiene tendencia)
      y_start = row['y']
      pendiente = row['m']
      if (dias < np.where(dataset.fc==row['fc'])[0] + lags):
        continue    
      serie = [] # Crea la serie que va a contener el precio proyectado
      serie = np.append(serie, np.repeat(np.nan, (np.where(dataset.fc==row['fc'])[0] + lags))) # Appendea nulos hasta el día en el que confirmamos que nació una tendencia
      i = np.where(dataset.fc==row['fc'])[0] + lags
      while (i < dias):
        dia = i - (np.where(dataset.fc==row['fc'])[0] + lags)
        serie = np.append(serie, (y_start + pendiente*lags) + pendiente*dia)
        i = i + 1 # Appendea el precio proyectado hasta el final

      colname = '%s_%s_proy' % (name, index)  # Precio proyectado
      dataset[colname] = serie # Construye la columna de toda la serie

      # Construyo columna con veces en la que el pico fue superado
      colname_pass = '%s_%s_pass' % (name, index) # Pico pasado
      if name == 'techos':
        dataset[colname_pass] = np.where(dataset['y']>(dataset[colname])*1.005, 1, 0)
      elif name == 'pisos':
        dataset[colname_pass] = np.where(dataset['y']<(dataset[colname])*0.995, 1, 0)
      dataset[colname_pass] = dataset[colname_pass].cumsum()

      # Construyo columna con veces en la que el pico fue probado
      colname_prueba = '%s_%s_prueba' % (name, index)  
      dataset[colname_prueba] = np.where((dataset['y']>dataset[colname]*0.995)&(dataset['y']<dataset[colname]*1.005), 1, 0)
      dataset[colname_prueba] = dataset[colname_prueba].cumsum()

      # Construyo columna con pendiente del pico
      colname_pendiente = '%s_%s_pendiente' % (name, index)  
      dataset[colname_pendiente] = row['m']

      # Creo la combinacion y elimino cada uno
      colname_comb = '%s_%s' % (name, index)
      dataset[colname_comb] = dataset[[colname, colname_pass, colname_prueba, colname_pendiente]].values.tolist()
      del dataset[colname]
      del dataset[colname_pass]
      del dataset[colname_prueba]
      del dataset[colname_pendiente]

  # Creo el objeto por cada techo o piso individual
  names_techos = dataset.filter(regex=("(techos)(.*)")).columns
  names_pisos = dataset.filter(regex=("(pisos)(.*)")).columns

  for index, row in dataset.iterrows():  # Por cada fila del dataset original (por cada precio)

    # Genero las rows vacías con las variables agregadas
    nu_pruebas_techo_vivo_mas_probado = np.nan    
    precio_proyectado_techo_vivo_mas_probado = np.nan
    precio_proyectado_techo_vivo_mas_cercano = np.nan
    precio_proyectado_techo_muerto_mas_cercano = np.nan
    tendencia_techo_vivo_mas_probado = np.nan

    nu_pruebas_piso_vivo_mas_probado = np.nan
    precio_proyectado_piso_vivo_mas_probado = np.nan
    precio_proyectado_piso_vivo_mas_cercano = np.nan
    precio_proyectado_piso_muerto_mas_cercano = np.nan
    tendencia_piso_vivo_mas_probado = np.nan

    # Voy a recorrer cada tendencia proyectada para definir cuáles van, en caso de que corresponda lo asigno a estas variables agregadas

    i = 0
    while i < len(row.index): # Por cada uno de los picos de los que se puede armar tendencia
      if (row.index[i] in names_techos):  # Si es un techo
        if row[i][1]>5: # Si está muerto
          if abs(row['y']-row[i][0]) < abs(row['y']-precio_proyectado_techo_muerto_mas_cercano) or np.isnan(precio_proyectado_techo_muerto_mas_cercano): # Si está muerto y proyecta precio más cercano que el actual
            precio_proyectado_techo_muerto_mas_cercano = row[i][0]
            
        else: # Si está vivo
          if row[i][2] > nu_pruebas_techo_vivo_mas_probado or (np.isnan(nu_pruebas_techo_vivo_mas_probado) and row[i][2]>0): # Si fue más probado que el actual
            nu_pruebas_techo_vivo_mas_probado = row[i][2]
            precio_proyectado_techo_vivo_mas_probado = row[i][0]
            tendencia_techo_vivo_mas_probado = row[i][3]

          if (np.isnan(precio_proyectado_techo_vivo_mas_cercano)) or (abs(row['y']-row[i][0]) < abs(row['y']-precio_proyectado_techo_vivo_mas_cercano)): # Si, sin haber muerto, proyecta un techo más alto que el actual
            precio_proyectado_techo_vivo_mas_cercano = row[i][0]

      elif (row.index[i] in names_pisos):
        if row[i][1]>5: # Si está muerto
          if abs(row['y']-row[i][0]) < abs(row['y']-precio_proyectado_piso_muerto_mas_cercano) or np.isnan(precio_proyectado_piso_muerto_mas_cercano): # Si proyecta precio más cercano que el actual
            precio_proyectado_piso_muerto_mas_cercano = row[i][0]
            
        else: # Si está vivo
          if row[i][2] > nu_pruebas_piso_vivo_mas_probado or (np.isnan(nu_pruebas_piso_vivo_mas_probado) and row[i][2]>0): # Si fue más probado que el actual
            nu_pruebas_piso_vivo_mas_probado = row[i][2]
            precio_proyectado_piso_vivo_mas_probado = row[i][0]
            tendencia_piso_vivo_mas_probado = row[i][3]

          if (np.isnan(precio_proyectado_piso_vivo_mas_cercano)) or (abs(row['y']-row[i][0]) < abs(row['y']-precio_proyectado_piso_vivo_mas_cercano)): # Si, sin haber muerto, proyecta un techo más alto que el actual
            precio_proyectado_piso_vivo_mas_cercano = row[i][0]
      i = i + 1
        
    dataset.loc[index,'nu_pruebas_techo_vivo_mas_probado_'f"{lags}"] = nu_pruebas_techo_vivo_mas_probado
    dataset.loc[index,'precio_proyectado_techo_vivo_mas_probado_'f"{lags}"] = (precio_proyectado_techo_vivo_mas_probado - row['y'])/row['y']
    dataset.loc[index,'precio_proyectado_techo_vivo_mas_cercano_'f"{lags}"] = (precio_proyectado_techo_vivo_mas_cercano - row['y'])/row['y']
    dataset.loc[index,'precio_proyectado_techo_muerto_mas_cercano_'f"{lags}"] = (precio_proyectado_techo_muerto_mas_cercano - row['y'])/row['y']
    dataset.loc[index,'tendencia_techo_vivo_mas_probado_'f"{lags}"] = tendencia_techo_vivo_mas_probado/row['y']

    dataset.loc[index,'nu_pruebas_piso_vivo_mas_probado_'f"{lags}"] = nu_pruebas_piso_vivo_mas_probado
    dataset.loc[index,'precio_proyectado_piso_vivo_mas_probado_'f"{lags}"] = (precio_proyectado_piso_vivo_mas_probado - row['y'])/row['y']
    dataset.loc[index,'precio_proyectado_piso_vivo_mas_cercano_'f"{lags}"] = (precio_proyectado_piso_vivo_mas_cercano - row['y'])/row['y']
    dataset.loc[index,'precio_proyectado_piso_muerto_mas_cercano_'f"{lags}"] = (precio_proyectado_piso_muerto_mas_cercano - row['y'])/row['y']
    dataset.loc[index,'tendencia_piso_vivo_mas_probado_'f"{lags}"] = tendencia_piso_vivo_mas_probado/row['y']

  i = 1
  while i < (lags+1):
      colname = 'p%sb' % (i)                                                  
      dataset = dataset.drop(colname, axis=1)
      j = i * -1
      colname = 'p%sf' % (-j)                                                  
      dataset = dataset.drop(colname, axis=1)
      i = i + 1

  ultimas_drop = ['maxb', 'maxf', 'minb', 'minf', 'T', 'P']
  dataset = dataset.drop(ultimas_drop, axis=1)
  dataset = dataset.drop(names_techos, axis=1)
  dataset = dataset.drop(names_pisos, axis=1)
  return dataset

# %%
def calcula_target_class(dataset, SL, TG, dias_indeterminacion):
  dataset['target'] = 99
  i = 1
  while i <= dias_indeterminacion:
    var_y_low = dataset.low.shift(-i)/df.y-1 # Variación del mínimo de cada día contra el precio de compra
    var_y_high = dataset.high.shift(-i)/df.y-1 # Variación del máximo de cada día contra el precio de compra
    target = np.where(var_y_low < -SL, 0, 99)
    target = np.where(var_y_high > TG, 1, target)
    dataset['target'] = np.where(dataset['target'] == 99 , target , dataset['target'])
    i = i + 1
#  df = df.iloc[:-dias_indeterminacion]  # Elimino las últimas filas que no llegan a tener target
  return dataset

# %%
def divide_dev_test(dataset, start_train, start_test, end_test):
  global df, x_dev, y_dev, x_test, y_test, x_val, y_val, df_test, df_dev
  month = dataset['fc'].dt.strftime('%Y%m')
  month = pd.to_numeric(month)
  if 'month' not in dataset:
    dataset.insert (1, "month", month)
  dataset = dataset[(dataset.target) < 90] # Elimina indeterminados

  df_dev = dataset[(dataset.month >= start_train) & (dataset.month < start_test)]
  df_test = dataset[(dataset.month >= start_test) & (dataset.month <= end_test)]

# %% [markdown]
# ## Consolidado

# %%
dias_empieza = 2500
dias_termina = 200
today = date.today()
fc_empieza = today + timedelta(days=(dias_empieza*-1))
fc_termina = today + timedelta(days=(dias_termina*-1))

#mvl = yf.download('^MERV', start=fc_empieza, end=fc_termina)
#print("Descargado Merval")
#mvl = mvl[['Close']]
#mvl.reset_index(level=0, inplace=True)
#mvl.columns=['fc','mvl']
base = pd.DataFrame()

for ticker in (
  'BTC-USD',
  'ETH-USD',
  'USDT-USD',
  'XRP-USD',
  'ADA-USD',
  'LTC-USD',
  'BCH-USD',
  'LINK-USD',
  'BNB-USD',
  'XLM-USD',
  'USDC-USD',
  'BSV-USD',
  'XMR-USD',
  'EOS-USD',
  'VET-USD',
  'XTZ-USD',
  'TRX-USD',
  'XEM-USD',
  'THETA-USD',
  'NEO-USD',
  'ATOM1-USD',
  'CCXX-USD',
  'MIOTA-USD',
  'DASH-USD',
  'CEL-USD',
  'DFI-USD',
  'ZEC-USD',
  'AVAX-USD',
  'SOL1-USD',
  'ETC-USD',
  'KSM-USD',
  'ZIL-USD',
  'WAVES-USD',
  'DCR-USD',
  'HBAR-USD',
  'ALGO-USD',
  'LRC-USD',
  'OMG-USD',
  'ONT-USD',
  'CTC1-USD'
):
  df = descarga(ticker, fc_empieza, fc_termina) # (Días empieza, días termina)
  print("Descargado ", ticker)
  # df = calcula_pc_merval(df)
  df = calcula_amplitud(df)
  df = estandariza_volumen(df)
 
  df = calcula_medias(df)
  df = df.dropna()
  df = calcula_historia(df, 5) # (Lags)
  df = calcula_canalidad_y(df)
  df = calcula_canalidad_histog_macd(df)
  
  for per in (360, 120, 90, 60, 30, 15, 8, 4):
    df = calcula_AT_tendencias(df,per)
    print("Calculé AT para", ticker, "en lags de", per)
  
  df = calcula_target_class(df, 0.06, 0.14, 90) # (Stop loss, Take gain, Días para indeterminación)
  base = base.append(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Descargado  BTC-USD
# Calculé AT para BTC-USD en lags de 360
# Calculé AT para BTC-USD en lags de 120
# Calculé AT para BTC-USD en lags de 90
# Calculé AT para BTC-USD en lags de 60
# Calculé AT para BTC-USD en lags de 30
# Calculé AT para BTC-USD en lags de 15
# Calculé AT para BTC-USD en lags de 8
# Calculé AT para BTC-USD en lags de 4
# [*********************100%***********************]  1 of 1 completed
# Descargado  ETH-USD
# Calculé AT para ETH-USD en lags de 360
# Calculé AT para ETH-USD en lags de 120
# Calculé AT para ETH-USD en lags de 90
# Calculé AT para ETH-USD en lags de 60
# Calculé AT para ETH-USD en lags de 30
# Calculé AT para ETH-USD en lags de 15
# Calculé AT para ETH-USD en lags de 8
# Calculé AT para ETH-USD en lags de 4
# [*********************100%***********************]  1 of 1 completed
# Descargado  USDT-USD
# Calculé AT para USDT-USD en lags de 360
# Calculé AT para USDT-USD en lags de 120
# Calculé AT para USDT-USD en lags de 90
# Calculé AT para USDT-USD en lags de 60
# Calculé AT para USDT-USD en lags de 30
# Calculé AT para USDT-USD en lags de 15
# Calculé AT para USDT-USD en lags de 8
# Calculé AT para USDT-USD en lags de 4
# [*********************100%***********************]  1 of 1 completed
# Descargado  XRP-USD
# Calculé AT para XRP-USD en lags de 360
# Calculé AT para XRP-USD en lags de 120
# Calculé AT para XRP-USD en lags de 90
# Calculé AT para XRP-USD en lags de 60
# Calculé AT para XRP-USD en lags de 30
# Calculé AT para XRP-USD en lags de 15
# Calculé AT para XRP-USD en lags de 8
# Calculé AT para XRP-USD en lags de 4
# [*********************100%***********************]  1 of 1 completed
# Descargado  ADA-USD
# Calculé AT para ADA-USD en lags de 360
# Calculé AT para ADA-USD en lags de 120
# Calculé AT para ADA-USD en lags de 90
# Calculé AT para ADA-USD en lags de 60
# Calculé AT para ADA-USD en lags de 30
# Calculé AT para ADA-USD en lags de 15
# Calculé AT para ADA-USD en lags de 8
# Calculé AT para ADA-USD en lags de 4
# [*********************100%***********************]  1 of 1 completed
# Descargado  LTC-USD
# Calculé AT para LTC-USD en lags de 360
# Calculé AT para LTC-USD en lags de 120
# Calculé AT para LTC-USD en lags de 90
# Calculé AT para LTC-USD en lags de 60
# Calculé AT para LTC-USD en lags de 30
# Calculé AT para LTC-USD en lags de 15
# Calculé AT para LTC-USD en lags de 8
# Calculé AT para LTC-USD en lags de 4
# [*********************100%***********************]  1 of 1 completed
# Descargado  BCH-USD
# Calculé AT para BCH-USD en lags de 360
# Calculé AT para BCH-USD en lags de 120
# Calculé AT para BCH-USD en lags de 90
# Calculé AT para BCH-USD en lags de 60
# Calculé AT para BCH-USD en lags de 30
# Calculé AT para BCH-USD en lags de 15
# Calculé AT para BCH-USD en lags de 8
# Calculé AT para BCH-USD en lags de 4
# [*********************100%***********************]  1 of 1 completed
# Descargado  LINK-USD
# Calculé AT para LINK-USD en lags de 360
# Calculé AT para LINK-USD en lags de 120
# Calculé AT para LINK-USD en lags de 90
# Calculé AT para LINK-USD en lags de 60
# Calculé AT para LINK-USD en lags de 30
# Calculé AT para LINK-USD en lags de 15
# Calculé AT para LINK-USD en lags de 8
# Calculé AT para LINK-USD en lags de 4
# [*********************100%***********************]  1 of 1 completed
# Descargado  BNB-USD
# Calculé AT para BNB-USD en lags de 360
# Calculé AT para BNB-USD en lags de 120
# Calculé AT para BNB-USD en lags de 90
# Calculé AT para BNB-USD en lags de 60
# Calculé AT para BNB-USD en lags de 30
# Calculé AT para BNB-USD en lags de 15
# Calculé AT para BNB-USD en lags de 8
# Calculé AT para BNB-USD en lags de 4
# [*********************100%***********************]  1 of 1 completed
# Descargado  XLM-USD
# Calculé AT para XLM-USD en lags de 360
# Calculé AT para XLM-USD en lags de 120
# Calculé AT para XLM-USD en lags de 90
# Calculé AT para XLM-USD en lags de 60
# Calculé AT para XLM-USD en lags de 30
# Calculé AT para XLM-USD en lags de 15
# Calculé AT para XLM-USD en lags de 8
# Calculé AT para XLM-USD en lags de 4

# %%
dias_empieza = 6500
dias_termina = 200
today = date.today()
fc_empieza = today + timedelta(days=(dias_empieza*-1))
fc_termina = today + timedelta(days=(dias_termina*-1))

df = descarga('^GSPC', fc_empieza, fc_termina) # (Días empieza, días termina)
df = calcula_amplitud(df)
df = estandariza_volumen(df)

df = calcula_medias(df)
del df['exp1']
del df['exp2']
del df['exp3']

df = df.dropna()
df = calcula_historia(df, 3) # (Lags)

df['target'] = (df.y.shift(-10)/df.y) - 1
df = df.dropna()
df
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
from google.colab import files
df.to_csv('df.csv') 
files.download('df.csv')

# %% [markdown]
# ## Working

# %% [markdown]
# 1.   **OBJETIVOS**:
#
# *   Imposible: Tener un modelo entrenado una sola vez, capaz de predecir correctamente alzas y bajas en todos los períodos.
# *   Posible: Tener un script que sepa cada cuanto entrenarse y por cuánto va a valer prediciendo correctamente alzas y bajas en todos los períodos.
# *   Realista: Si no va a predecir alzas y bajas correctamente en todos los períodos, que sea capaz de predecir alzas O bajas correctamente.
#
# 2.   **PREGUNTAS**:
#
# *   ¿Cuántos meses para entrenar? ¿Cuántos meses para testear? ¿Es igualmente efectivo en todos los meses?
# *   ¿Cómo garantizar en el testeo que no se trate de un éxito por aciertos muy juntos, sea en mismo activo o en diferentes activos pero los mismos días?
# *   ¿Cómo medir, al final de todo, la comparación entre usar el modelo y comprar el activo en el plazo?
# *   ¿Cómo optimizar los parámetros? ¿Incluir en los parámetros el número de rondas, el SL y el TG?
#
# 3.   **TO DO**:
#
# *   Modificar la lógica de los deciles, por una que vaya generando la posición del activo, sumando en cada 1 que haya, y compararla con solo tener el activo..

# %% [markdown]
# ### XGBoost

# %%
month = base['fc'].dt.strftime('%Y%m')
month = pd.to_numeric(month)
if 'month' not in base:
  base.insert (1, "month", month)

base = base[(base.target) < 90] # Elimina indeterminados
base = base.sort_values(by=['fc'])
un_quintos = int(len(base)/5)
dos_quintos = int(len(base)/5)*2
cuatro_quintos = int(len(base)/5)*4
base_params = base.iloc[un_quintos:dos_quintos]
base_train = base.iloc[dos_quintos:cuatro_quintos]
base_test = base.iloc[cuatro_quintos:(len(base)-180)]

# Parametrizo

X=base_params.iloc[:, 7:].drop("target", 1)
targets=base_params.target

pred_train, pred_test, tar_train, tar_test = train_test_split(X, targets, test_size=.4)
eval_set = [(pred_train, tar_train),(pred_test, tar_test)]

bst=XGBClassifier(objective= 'binary:logistic',seed=5)
params = {  
    "n_estimators": st.randint(15, 100),
    "max_depth": st.randint(3, 4),
    "learning_rate": st.uniform(0.05, 0.3),
    "colsample_bytree": st.beta(10, 1) ,
    "subsample": st.beta(10, 1)  ,
    "gamma": st.uniform(0, 10),
    'reg_alpha': st.expon(0, 50),
    "min_child_weight": st.expon(0, 50)
                         }
gs = RandomizedSearchCV(bst, params,  n_iter=30, n_jobs=1,cv=4 )  
bst=gs.fit(pred_train, tar_train,eval_set=eval_set, eval_metric=["auc"],early_stopping_rounds=10) 

# Entreno

X=base_train.iloc[:, 7:].drop("target", 1)
targets=base_train.target

pred_train, pred_test, tar_train, tar_test = train_test_split(X, targets, test_size=.4)
eval_set = [(pred_train, tar_train),(pred_test, tar_test)]

classif = XGBClassifier(**bst.best_params_)
model=classif.fit(pred_train,tar_train,eval_set=eval_set, eval_metric=["auc"],early_stopping_rounds=10)
results = model.evals_result()

# Análisis

epochs = len(results['validation_0']['auc'])
x_axis = range(0, epochs)
# plot log loss
fig, ax = plt.subplots(figsize=(15, 8))
ax.plot(x_axis, results['validation_0']['auc'], label='Train')
ax.plot(x_axis, results['validation_1']['auc'], label='Test')
ax.legend()
plt.ylabel('auc')
plt.title('XGBoost auc')
plt.show()

importancia=model.feature_importances_ 
importancia=pd.DataFrame(importancia)
importancia=importancia.transpose()
importancia.columns=X.columns
b=importancia
c=b.transpose()
r=pd.DataFrame(c).loc[(c[0]>0),].sort_values([0],ascending=False)
r

# %%
# Test

X=base_test.iloc[:, 7:].drop("target", 1)
targets=base_test.target

preds = model.predict_proba(X)
A = preds[:,1]
data_ks=pd.DataFrame(targets)
data_ks['prob_suba'] = A
data_ks['bucket'] = pd.qcut(data_ks['prob_suba'].values, 50, duplicates='drop')
data_ks['no_target'] = 1 - data_ks['target']
grouped = data_ks.groupby('bucket', as_index = False)

agg1 = grouped.min().prob_suba
agg1 = pd.DataFrame({'min_prob_suba': grouped.min().prob_suba})
agg1['max_prob_suba'] = grouped.max().prob_suba
agg1['targets'] = grouped.sum().target
agg1['no_targets'] = grouped.sum().no_target
agg1['total'] = agg1.targets + agg1.no_targets
agg1['ganancia_esperada'] = (agg1.targets/agg1.total)*(0.14-0.015) - (agg1.no_targets/agg1.total)*(0.06-0.015)

agg1

# %%
id_test = base_test.iloc[:, 0:4]
id_test
id_test['pred'] = preds[:,1]
id_test['efec'] = base_test.target
id_test['result'] = np.where(((id_test['pred'] > 0.5) & (id_test['efec'] == 1)), 0.14 - 0.015, 
                    np.where(((id_test['pred'] > 0.5) & (id_test['efec'] == 0)), -0.06 - 0.015, 
                   0))

resumen = []

for activo in id_test.ticker.unique():
  un_activo = id_test[(id_test.ticker == activo)]
  for mes in un_activo.month.unique():
    un_mes = un_activo[(un_activo.month == mes)]
    ganancia_mensual = (un_mes.y[un_mes.index[-1]]/un_mes.y[un_mes.index[0]])-1
    ganancia_modelo = un_mes.result.sum()
    resumen.append([activo, mes, ganancia_modelo, ganancia_mensual])

ganancias = pd.DataFrame(resumen, columns=['activo', 'mes', 'ganancia_modelo', 'ganancia_mensual'])
groups = ganancias.groupby("activo")

for name, group in groups:
    plt.plot(group["ganancia_mensual"], group["ganancia_modelo"], marker="o", linestyle="", label=name)

orig = np.linspace(-0.1,0.1,3)
plt.plot(orig,orig,'k-') # identity line

# %%
for ticker in id_test.ticker.unique():
  toplot = id_test[(id_test.ticker == ticker)]

  ds = toplot[['fc']].to_numpy()
  y = toplot[['y']].to_numpy()

  ds_list = tuple(ds.reshape(1, -1)[0])
  efec_lis = toplot['efec'].tolist()
  col = []
  for vela in efec_lis:
      if vela < 0.50:
          col.append('red')
      elif vela >= 0.50:
          col.append('green')

  pred_list = toplot['pred'].tolist()
  y_pos = np.arange(len(ds_list))

  plt.figure(figsize=(12,8))
  plt.subplot(211)
  plt.title(ticker) 
  plt.bar(y_pos, pred_list, color=col)
  plt.subplot(212)
  plt.plot(ds, y)
  plt.show()

# %% [markdown]
# ### Stops

# %%
# por lo que vi hasta ahora, 0.06 y 0.14 son buenos candidatos

descarga("YPFD.BA", 4000, 2) # (Días empieza, días termina)
dias_cierre = 30
resumen_stop = []
x = range(4, 20, 1)
y = range(4, 20, 1)
for m in y:
  TG = (m*0.01)
  for n in x:
    SL = (n*-0.01)
    i = 1
    while i <= dias_cierre:
      var_y_cierre = df.y.shift(-dias_cierre)/df.y-1
      var_y_low = df.low.shift(-i)/df.y-1 # Variación del mínimo de cada día contra el precio de compra
      var_y_high = df.high.shift(-i)/df.y-1 # Variación del máximo de cada día contra el precio de compra
      target = np.where(var_y_low < SL, SL-0.015, 99)
      target = np.where(var_y_high > TG, TG-0.015, target)
      df['target'] = target
      df['target'] = np.where(df['target'] == 99 , var_y_cierre , df['target'])
      i = i + 1
    
    results = df.target.dropna()
    positivos = len(df.loc[df.target > 0])
    negativos = len(df.loc[df.target < 0])
    avg = df.target.mean()
    resumen_stop.append([SL, TG, avg, positivos, negativos])
    
resumen_stop = pd.DataFrame(resumen_stop, columns=['SL', 'TG', 'avg', 'pos', 'neg'])
resumen_stop.sort_values(by=['avg'], ascending=False)

# %%
descarga("YPFD.BA", 300, 2)
SL = -0.1
TG = 0.1
i = 1
dias_cierre = 5
df['target'] = 99
while i <= dias_cierre:
  var_y_cierre = df.y.shift(-dias_cierre)/df.y-1
  var_y_low = df.low.shift(-i)/df.y-1 # Variación del mínimo de cada día contra el precio de compra
  var_y_high = df.high.shift(-i)/df.y-1 # Variación del máximo de cada día contra el precio de compra
  target = np.where(var_y_low < SL, SL-0.015, 99)
  target = np.where(var_y_high > TG, TG-0.015, target)
  df['target'] = target
  df['target'] = np.where(df['target'] == 99 , var_y_cierre , df['target'])
  i = i + 1
df = df[(df.target>0)|(df.target<0)]
p5 = np.percentile(df.target, 5)
p5

# %%
def multi_analisis_rf(dataset, semillas):
  global df, x_dev, y_dev, x_test, y_test, x_val, y_val, y_pred_prob, y_pred
  x_dev, x_test, y_dev, y_test = train_test_split(X_dev, y_dev, test_size=0.25, random_state=0)

  n_seeds = semillas
  accs = []
  precisions = []
  recalls = []
  f1s = []
  f1s_two = []

  for seed in range(n_seeds):
    x_train, x_val, y_train, y_val = train_test_split(x_dev, y_dev, test_size=0.2, random_state=seed, stratify=y_dev) 

    sc = StandardScaler()
    x_train = sc.fit_transform(x_train)
    x_val = sc.transform(x_val)

    classifier = RandomForestClassifier()
    classifier = classifier.fit(x_train, y_train)
    y_pred = classifier.predict(x_val)
    y_pred_prob = classifier.predict(x_val)

    # Medimos (accuracy, precision, recall y f-scores) de nuestra predicción
    accs.append(accuracy_score(y_val,y_pred_val))
    precisions.append(precision_score(y_val,y_pred_val))
    recalls.append(recall_score(y_val,y_pred_val))
    f1s.append(f1_score(y_val,y_pred_val))
    f1s_two.append(fbeta_score(y_val, y_pred_val, beta=2))

  metric_labels = ['Accuracy']*len(accs) + ['Precision']*len(precisions) + ['Recall']*len(recalls) + ['F1 Score']*len(f1s) + ['F2 Score']*len(f1s_two)
  all_metrics = accs + precisions + recalls + f1s + f1s_two

  wanted_metric_labels = ['Precision']*len(precisions) + ['Recall']*len(recalls) + ['F2 Score']*len(f1s_two)
  wanted_metrics = precisions + recalls + f1s_two

  sns.set_context('talk')
  plt.figure(figsize=(15,8))
  return sns.boxplot(metric_labels,all_metrics)

# %% [markdown]
# ### Tendencias

# %%
# GRAFICAR (relación: dias_empieza=25*lags)
dias_empieza = 1200
dias_termina = 2
today = date.today()
fc_empieza = today + timedelta(days=(dias_empieza*-1))
fc_termina = today + timedelta(days=(dias_termina*-1))

descarga("YPFD.BA", fc_empieza, fc_termina) # (Días empieza, días termina)

lags = 48

i = 1
while i < (lags+1):
    colname = 'p%sb' % (i)                                                  
    df[colname] = round(df.y.shift(i),2)
    j = i * -1
    colname = 'p%sf' % (-j)                                                  
    df[colname] = round(df.y.shift(j),2)
    i = i + 1

df['maxb'] = round(df.filter(regex=(".*b")).max(axis=1),2)
df['maxf']= round(df.filter(regex=(".*f")).max(axis=1),2)
df['minb'] = round(df.filter(regex=(".*b")).min(axis=1),2)
df['minf'] = round(df.filter(regex=(".*f")).min(axis=1),2)
df['techo'] = np.where((df['y']>df['maxb']) & (df['y']>df['maxf']), 1, 0)
df['piso'] = np.where((df['y']<df['minb']) & (df['y']<df['minf']), 1, 0)
techos = df[(df['techo']==1)]
techos['m'] = (techos.y.shift(1) - techos.y)/(techos.fc.shift(1) - techos.fc).dt.days

pisos = df[(df['piso']==1)]
pisos['m'] = (pisos.y.shift(1) - pisos.y)/(pisos.fc.shift(1) - pisos.fc).dt.days

df_list = [techos, pisos]

for df_picos in df_list:  # En cada df (techos y pisos)
  name = [x for x in globals() if globals()[x] is df_picos][0]
  dias = len(df)
  for index, row in df_picos.iloc[1:].iterrows(): # Para cada pico detectado
    y_start = row['y']
    pendiente = row['m']
    if (dias < np.where(df.fc==row['fc'])[0] + lags):
      continue    
    serie = []
    serie = np.append(serie, np.repeat(np.nan, (np.where(df.fc==row['fc'])[0] + lags)))
    i = np.where(df.fc==row['fc'])[0] + lags
    while (i < dias):
      dia = i - (np.where(df.fc==row['fc'])[0] + lags)
      serie = np.append(serie, (y_start + pendiente*lags) + pendiente*dia)
      i = i + 1

    colname = '%s_%s_proy' % (name, index)  # Precio proyectado
    df[colname] = serie # Construye la columna de toda la serie

    colname_pass = '%s_%s_pass' % (name, index) # Pico pasado
    if name == 'techos':
      df[colname_pass] = np.where(df['y']>(df[colname])*1.005, 1, 0)
    else:
      df[colname_pass] = np.where(df['y']<(df[colname])*0.995, 1, 0)
    df[colname_pass] = df[colname_pass].cumsum()

    colname_prueba = '%s_%s_prueba' % (name, index)  
    df[colname_prueba] = np.where((df['y']>df[colname]*0.995)&(df['y']<df[colname]*1.005), 1, 0)
    df[colname_prueba] = df[colname_prueba].cumsum()
'''
    if ((df[colname_pass].sum() > 1)):
      del df[colname]
      del df[colname_pass]
      del df[colname_prueba]
'''
toplot = df.filter(regex=("fc|y|techos(.*)proy|pisos(.*)proy"))
toplot.plot(x='fc', figsize=(10, 5))

# %% [markdown]
# ## Otros

# %%
from sklearn.model_selection import StratifiedKFold, KFold, GridSearchCV, RandomizedSearchCV

best_tree = None
best_score = None

kfoldcv = StratifiedKFold(n_splits=50)

for train_index, test_index in kfoldcv.split(x_dev, y_dev):
  x_train, x_val = x_dev[train_index], x_dev[test_index]
  y_train, y_val = y_dev[train_index], y_dev[test_index]

  # Tree Classifier
  kfold_tree = DecisionTreeClassifier(max_depth=len(df.columns)-5,random_state=42)

  # Entrenamos al arbol
  kfold_tree.fit(x_train,y_train)

  # Ejecutamos nuestra predicción
  y_pred_val = kfold_tree.predict(x_val)

  f2score = fbeta_score(y_val, y_pred_val, beta=2)

  if best_score is None or best_score < f2score:
    best_score = f2score
    best_tree = kfold_tree

features =  df.iloc[:, 5:-2].columns

feat_imps = best_tree.feature_importances_
for feat_imp,feat in sorted(zip(feat_imps,features)):
  if feat_imp>0:
    print('{}: {}'.format(feat,feat_imp))

# %%
df.hist(column='target')
df.target.value_counts()

# %%
import pickle
pickle.dump(model, open("v1/model.dat", "wb"))

# %%
prueba = pickle.load(open("v1/model.dat", "rb"))

# %%
# Redefino target
dias = 30
pc = 0.25

base = base.sort_values(["ticker", "fc"], ascending = (False, True))
base['target_alza'] = np.where(base.y.shift(-dias) > base.y * (1+pc), 1, 0)
base['target_alza'] = np.where(base.ticker != base.ticker.shift(-dias), np.nan, base.target_alza)
base['target_baja'] = np.where(base.y.shift(-dias) < base.y * (1-pc), 1, 0)
base['target_baja'] = np.where(base.ticker != base.ticker.shift(-dias), np.nan, base.target_baja)
base = base.sort_values(["fc"], ascending = (True)) # KS 11
base = base[(base.target) < 90] # Elimina indeterminados
base = base[(base.target_alza) >= 0] # Elimina indeterminados
base = base[(base.target_baja) >= 0] # Elimina indeterminados

base = base.sort_values(by=['fc'])
un_quintos = int(len(base)/5)
dos_quintos = int(len(base)/5)*2
cuatro_quintos = int(len(base)/5)*4
base_params = base.iloc[un_quintos:dos_quintos]
base_train = base.iloc[dos_quintos:cuatro_quintos]
base_test = base.iloc[cuatro_quintos:(len(base)-180)]

# Target si subió 10% en 30 días

# Parametrizo
X=base_params.iloc[:, 7:].drop(["target_alza", "target_baja", "target"], 1)
targets=base_params.target_alza
pred_train, pred_test, tar_train, tar_test = train_test_split(X, targets, test_size=.4)
eval_set = [(pred_train, tar_train),(pred_test, tar_test)]
bst=XGBClassifier(objective= 'binary:logistic',seed=5)
params = {  
    "n_estimators": st.randint(15, 100),
    "max_depth": st.randint(3, 4),
    "learning_rate": st.uniform(0.05, 0.3),
    "colsample_bytree": st.beta(10, 1) ,
    "subsample": st.beta(10, 1)  ,
    "gamma": st.uniform(0, 10),
    'reg_alpha': st.expon(0, 50),
    "min_child_weight": st.expon(0, 50)
                         }
gs = RandomizedSearchCV(bst, params,  n_iter=20, n_jobs=1,cv=4 )  
bst=gs.fit(pred_train, tar_train,eval_set=eval_set, eval_metric=["auc"],early_stopping_rounds=10) 

# Entreno
X=base_train.iloc[:, 7:].drop(["target_alza", "target_baja", "target"], 1)
targets=base_train.target_alza
pred_train, pred_test, tar_train, tar_test = train_test_split(X, targets, test_size=.4)
eval_set = [(pred_train, tar_train),(pred_test, tar_test)]
classif = XGBClassifier(**bst.best_params_)
model_alza=classif.fit(pred_train,tar_train,eval_set=eval_set, eval_metric=["auc"],early_stopping_rounds=10)

# Target si bajó 10% en 30 días

# Parametrizo
X=base_params.iloc[:, 7:].drop(["target_alza", "target_baja", "target"], 1)
targets=base_params.target_baja
pred_train, pred_test, tar_train, tar_test = train_test_split(X, targets, test_size=.4)
eval_set = [(pred_train, tar_train),(pred_test, tar_test)]
bst=XGBClassifier(objective= 'binary:logistic',seed=5)
params = {  
    "n_estimators": st.randint(15, 100),
    "max_depth": st.randint(3, 4),
    "learning_rate": st.uniform(0.05, 0.3),
    "colsample_bytree": st.beta(10, 1) ,
    "subsample": st.beta(10, 1)  ,
    "gamma": st.uniform(0, 10),
    'reg_alpha': st.expon(0, 50),
    "min_child_weight": st.expon(0, 50)
                         }
gs = RandomizedSearchCV(bst, params,  n_iter=20, n_jobs=1,cv=4 )  
bst=gs.fit(pred_train, tar_train,eval_set=eval_set, eval_metric=["auc"],early_stopping_rounds=10) 

# Entreno
X=base_train.iloc[:, 7:].drop(["target_alza", "target_baja", "target"], 1)
targets=base_train.target_baja
pred_train, pred_test, tar_train, tar_test = train_test_split(X, targets, test_size=.4)
eval_set = [(pred_train, tar_train),(pred_test, tar_test)]
classif = XGBClassifier(**bst.best_params_)
model_baja=classif.fit(pred_train,tar_train,eval_set=eval_set, eval_metric=["auc"],early_stopping_rounds=10)
# Out:
# [0]	validation_0-auc:0.700539	validation_1-auc:0.685149
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.710164	validation_1-auc:0.687943
# [2]	validation_0-auc:0.745365	validation_1-auc:0.725016
# [3]	validation_0-auc:0.76796	validation_1-auc:0.746783
# [4]	validation_0-auc:0.766441	validation_1-auc:0.743944
# [5]	validation_0-auc:0.764863	validation_1-auc:0.739811
# [6]	validation_0-auc:0.767619	validation_1-auc:0.740672
# [7]	validation_0-auc:0.767949	validation_1-auc:0.740482
# [8]	validation_0-auc:0.767949	validation_1-auc:0.740482
# [9]	validation_0-auc:0.776306	validation_1-auc:0.742071
# [10]	validation_0-auc:0.788797	validation_1-auc:0.752366
# [11]	validation_0-auc:0.793592	validation_1-auc:0.759607
# [12]	validation_0-auc:0.793592	validation_1-auc:0.759607
# [13]	validation_0-auc:0.806697	validation_1-auc:0.770089
# [14]	validation_0-auc:0.806697	validation_1-auc:0.770089
# [15]	validation_0-auc:0.806697	validation_1-auc:0.770089
# [16]	validation_0-auc:0.806697	validation_1-auc:0.770089
# [17]	validation_0-auc:0.806697	validation_1-auc:0.770089
# [18]	validation_0-auc:0.806697	validation_1-auc:0.770089
# [19]	validation_0-auc:0.806697	validation_1-auc:0.770089
# [20]	validation_0-auc:0.806697	validation_1-auc:0.770089
# [21]	validation_0-auc:0.806697	validation_1-auc:0.770089
# [22]	validation_0-auc:0.806697	validation_1-auc:0.770089
# [23]	validation_0-auc:0.806697	validation_1-auc:0.770089
# Stopping. Best iteration:
# [13]	validation_0-auc:0.806697	validation_1-auc:0.770089
#
# [0]	validation_0-auc:0.654485	validation_1-auc:0.617091
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.707176	validation_1-auc:0.674649
# [2]	validation_0-auc:0.718467	validation_1-auc:0.691659
# [3]	validation_0-auc:0.733164	validation_1-auc:0.701781
# [4]	validation_0-auc:0.73354	validation_1-auc:0.702392
# [5]	validation_0-auc:0.764967	validation_1-auc:0.729413
# [6]	validation_0-auc:0.778771	validation_1-auc:0.741015
# [7]	validation_0-auc:0.78157	validation_1-auc:0.744041
# [8]	validation_0-auc:0.78157	validation_1-auc:0.744041
# [9]	validation_0-auc:0.78157	validation_1-auc:0.744041
# [10]	validation_0-auc:0.787027	validation_1-auc:0.751916
# [11]	validation_0-auc:0.787027	validation_1-auc:0.751916
# [12]	validation_0-auc:0.787104	validation_1-auc:0.75155
# [13]	validation_0-auc:0.787104	validation_1-auc:0.75155
# [14]	validation_0-auc:0.787104	validation_1-auc:0.75155
# [15]	validation_0-auc:0.787104	validation_1-auc:0.75155
# [16]	validation_0-auc:0.787104	validation_1-auc:0.75155
# [17]	validation_0-auc:0.787104	validation_1-auc:0.75155
# [18]	validation_0-auc:0.787104	validation_1-auc:0.75155
# [19]	validation_0-auc:0.787104	validation_1-auc:0.75155
# [20]	validation_0-auc:0.787104	validation_1-auc:0.75155
# Stopping. Best iteration:
# [10]	validation_0-auc:0.787027	validation_1-auc:0.751916
#
# [0]	validation_0-auc:0.696874	validation_1-auc:0.677719
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.708574	validation_1-auc:0.68942
# [2]	validation_0-auc:0.741089	validation_1-auc:0.721947
# [3]	validation_0-auc:0.741211	validation_1-auc:0.722283
# [4]	validation_0-auc:0.748805	validation_1-auc:0.732796
# [5]	validation_0-auc:0.782511	validation_1-auc:0.763549
# [6]	validation_0-auc:0.790418	validation_1-auc:0.768492
# [7]	validation_0-auc:0.798407	validation_1-auc:0.780929
# [8]	validation_0-auc:0.798407	validation_1-auc:0.780929
# [9]	validation_0-auc:0.810581	validation_1-auc:0.792449
# [10]	validation_0-auc:0.812675	validation_1-auc:0.793901
# [11]	validation_0-auc:0.812675	validation_1-auc:0.793901
# [12]	validation_0-auc:0.813065	validation_1-auc:0.79203
# [13]	validation_0-auc:0.813065	validation_1-auc:0.79203
# [14]	validation_0-auc:0.813065	validation_1-auc:0.79203
# [15]	validation_0-auc:0.813065	validation_1-auc:0.79203
# [16]	validation_0-auc:0.813065	validation_1-auc:0.79203
# [17]	validation_0-auc:0.813065	validation_1-auc:0.79203
# [18]	validation_0-auc:0.813065	validation_1-auc:0.79203
# [19]	validation_0-auc:0.813065	validation_1-auc:0.79203
# [20]	validation_0-auc:0.813065	validation_1-auc:0.79203
# Stopping. Best iteration:
# [10]	validation_0-auc:0.812675	validation_1-auc:0.793901
#
# [0]	validation_0-auc:0.701337	validation_1-auc:0.68387
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.706862	validation_1-auc:0.687687
# [2]	validation_0-auc:0.748626	validation_1-auc:0.728347
# [3]	validation_0-auc:0.749757	validation_1-auc:0.728854
# [4]	validation_0-auc:0.752507	validation_1-auc:0.729102
# [5]	validation_0-auc:0.756258	validation_1-auc:0.736003
# [6]	validation_0-auc:0.779045	validation_1-auc:0.748117
# [7]	validation_0-auc:0.779045	validation_1-auc:0.748117
# [8]	validation_0-auc:0.779045	validation_1-auc:0.748117
# [9]	validation_0-auc:0.779045	validation_1-auc:0.748117
# [10]	validation_0-auc:0.779045	validation_1-auc:0.748117
# [11]	validation_0-auc:0.779578	validation_1-auc:0.749249
# [12]	validation_0-auc:0.779578	validation_1-auc:0.749249
# [13]	validation_0-auc:0.779578	validation_1-auc:0.749249
# [14]	validation_0-auc:0.779578	validation_1-auc:0.749249
# [15]	validation_0-auc:0.779578	validation_1-auc:0.749249
# [16]	validation_0-auc:0.779578	validation_1-auc:0.749249
# [17]	validation_0-auc:0.779578	validation_1-auc:0.749249
# [18]	validation_0-auc:0.779578	validation_1-auc:0.749249
# [19]	validation_0-auc:0.776319	validation_1-auc:0.749128
# [20]	validation_0-auc:0.776319	validation_1-auc:0.749128
# [21]	validation_0-auc:0.776319	validation_1-auc:0.749128
# Stopping. Best iteration:
# [11]	validation_0-auc:0.779578	validation_1-auc:0.749249
#
# [0]	validation_0-auc:0.709695	validation_1-auc:0.698539
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.7135	validation_1-auc:0.701528
# [2]	validation_0-auc:0.713805	validation_1-auc:0.701403
# [3]	validation_0-auc:0.715264	validation_1-auc:0.696313
# [4]	validation_0-auc:0.740713	validation_1-auc:0.719992
# [5]	validation_0-auc:0.751323	validation_1-auc:0.73312
# [6]	validation_0-auc:0.755276	validation_1-auc:0.735779
# [7]	validation_0-auc:0.760761	validation_1-auc:0.73915
# [8]	validation_0-auc:0.765912	validation_1-auc:0.741816
# [9]	validation_0-auc:0.771092	validation_1-auc:0.74179
# [10]	validation_0-auc:0.775443	validation_1-auc:0.743448
# [11]	validation_0-auc:0.776168	validation_1-auc:0.743967
# [12]	validation_0-auc:0.77769	validation_1-auc:0.743863
# [13]	validation_0-auc:0.778458	validation_1-auc:0.744117
# [14]	validation_0-auc:0.77851	validation_1-auc:0.743286
# [15]	validation_0-auc:0.789387	validation_1-auc:0.75524
# [16]	validation_0-auc:0.791717	validation_1-auc:0.756729
# [17]	validation_0-auc:0.792465	validation_1-auc:0.757526
# [18]	validation_0-auc:0.793268	validation_1-auc:0.757276
# [19]	validation_0-auc:0.794336	validation_1-auc:0.758933
# [20]	validation_0-auc:0.797686	validation_1-auc:0.762123
# [21]	validation_0-auc:0.802214	validation_1-auc:0.765405
# [22]	validation_0-auc:0.804421	validation_1-auc:0.769063
# [23]	validation_0-auc:0.802877	validation_1-auc:0.767405
# [24]	validation_0-auc:0.80274	validation_1-auc:0.767095
# [25]	validation_0-auc:0.80238	validation_1-auc:0.766331
# [26]	validation_0-auc:0.804256	validation_1-auc:0.76724
# [27]	validation_0-auc:0.804256	validation_1-auc:0.76724
# [28]	validation_0-auc:0.807629	validation_1-auc:0.772369
# [29]	validation_0-auc:0.806802	validation_1-auc:0.771146
# [30]	validation_0-auc:0.806802	validation_1-auc:0.771146
# [31]	validation_0-auc:0.806802	validation_1-auc:0.771146
# [32]	validation_0-auc:0.808237	validation_1-auc:0.772465
# [33]	validation_0-auc:0.808237	validation_1-auc:0.772465
# [34]	validation_0-auc:0.80847	validation_1-auc:0.773288
# [35]	validation_0-auc:0.810483	validation_1-auc:0.775522
# [36]	validation_0-auc:0.812214	validation_1-auc:0.776981
# [37]	validation_0-auc:0.815871	validation_1-auc:0.778782
# [38]	validation_0-auc:0.815871	validation_1-auc:0.778782
# [39]	validation_0-auc:0.815871	validation_1-auc:0.778782
# [40]	validation_0-auc:0.815871	validation_1-auc:0.778782
# [41]	validation_0-auc:0.815871	validation_1-auc:0.778782
# [42]	validation_0-auc:0.815871	validation_1-auc:0.778782
# [43]	validation_0-auc:0.815871	validation_1-auc:0.778782
# [44]	validation_0-auc:0.815871	validation_1-auc:0.778782
# [45]	validation_0-auc:0.815871	validation_1-auc:0.778782
# [46]	validation_0-auc:0.815871	validation_1-auc:0.778782
# [47]	validation_0-auc:0.815871	validation_1-auc:0.778782
# Stopping. Best iteration:
# [37]	validation_0-auc:0.815871	validation_1-auc:0.778782
#
# [0]	validation_0-auc:0.654485	validation_1-auc:0.617091
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.654485	validation_1-auc:0.617091
# [2]	validation_0-auc:0.703346	validation_1-auc:0.659277
# [3]	validation_0-auc:0.703346	validation_1-auc:0.659277
# [4]	validation_0-auc:0.7058	validation_1-auc:0.667889
# [5]	validation_0-auc:0.723596	validation_1-auc:0.676048
# [6]	validation_0-auc:0.729094	validation_1-auc:0.685703
# [7]	validation_0-auc:0.757248	validation_1-auc:0.715716
# [8]	validation_0-auc:0.761917	validation_1-auc:0.711837
# [9]	validation_0-auc:0.76285	validation_1-auc:0.714885
# [10]	validation_0-auc:0.761611	validation_1-auc:0.714702
# [11]	validation_0-auc:0.763342	validation_1-auc:0.716069
# [12]	validation_0-auc:0.766396	validation_1-auc:0.717533
# [13]	validation_0-auc:0.768887	validation_1-auc:0.719646
# [14]	validation_0-auc:0.767893	validation_1-auc:0.719511
# [15]	validation_0-auc:0.768148	validation_1-auc:0.720523
# [16]	validation_0-auc:0.771525	validation_1-auc:0.724586
# [17]	validation_0-auc:0.771163	validation_1-auc:0.725229
# [18]	validation_0-auc:0.773949	validation_1-auc:0.7276
# [19]	validation_0-auc:0.777374	validation_1-auc:0.731395
# [20]	validation_0-auc:0.779748	validation_1-auc:0.735174
# [21]	validation_0-auc:0.786079	validation_1-auc:0.741317
# [22]	validation_0-auc:0.786855	validation_1-auc:0.740817
# [23]	validation_0-auc:0.785394	validation_1-auc:0.740376
# [24]	validation_0-auc:0.786693	validation_1-auc:0.741025
# [25]	validation_0-auc:0.786382	validation_1-auc:0.74163
# [26]	validation_0-auc:0.78962	validation_1-auc:0.74615
# [27]	validation_0-auc:0.791664	validation_1-auc:0.750689
# [28]	validation_0-auc:0.791664	validation_1-auc:0.750689
# [29]	validation_0-auc:0.791664	validation_1-auc:0.750689
# [30]	validation_0-auc:0.79174	validation_1-auc:0.751658
# [31]	validation_0-auc:0.793305	validation_1-auc:0.751673
# [32]	validation_0-auc:0.793477	validation_1-auc:0.751593
# [33]	validation_0-auc:0.795876	validation_1-auc:0.756081
# [34]	validation_0-auc:0.797377	validation_1-auc:0.758365
# [35]	validation_0-auc:0.798904	validation_1-auc:0.761652
# [36]	validation_0-auc:0.800779	validation_1-auc:0.7636
# [37]	validation_0-auc:0.800779	validation_1-auc:0.7636
# [38]	validation_0-auc:0.800779	validation_1-auc:0.7636
# [39]	validation_0-auc:0.80245	validation_1-auc:0.765615
# [40]	validation_0-auc:0.80245	validation_1-auc:0.765615
# [41]	validation_0-auc:0.80245	validation_1-auc:0.765615
# [42]	validation_0-auc:0.802982	validation_1-auc:0.767963
# [43]	validation_0-auc:0.802982	validation_1-auc:0.767963
# [44]	validation_0-auc:0.802982	validation_1-auc:0.767963
# [45]	validation_0-auc:0.803818	validation_1-auc:0.768203
# [46]	validation_0-auc:0.803818	validation_1-auc:0.768203
# [47]	validation_0-auc:0.803818	validation_1-auc:0.768203
# [48]	validation_0-auc:0.803818	validation_1-auc:0.768203
# [49]	validation_0-auc:0.803818	validation_1-auc:0.768203
# [50]	validation_0-auc:0.803818	validation_1-auc:0.768203
# [51]	validation_0-auc:0.804941	validation_1-auc:0.770014
# [52]	validation_0-auc:0.804941	validation_1-auc:0.770014
# [53]	validation_0-auc:0.804941	validation_1-auc:0.770014
# [54]	validation_0-auc:0.804941	validation_1-auc:0.770014
# [55]	validation_0-auc:0.804941	validation_1-auc:0.770014
# [56]	validation_0-auc:0.804941	validation_1-auc:0.770014
# [57]	validation_0-auc:0.804941	validation_1-auc:0.770014
# [58]	validation_0-auc:0.804941	validation_1-auc:0.770014
# [59]	validation_0-auc:0.804941	validation_1-auc:0.770014
# [0]	validation_0-auc:0.707465	validation_1-auc:0.682531
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.714886	validation_1-auc:0.688298
# [2]	validation_0-auc:0.716098	validation_1-auc:0.689831
# [3]	validation_0-auc:0.719631	validation_1-auc:0.698694
# [4]	validation_0-auc:0.720001	validation_1-auc:0.698456
# [5]	validation_0-auc:0.720001	validation_1-auc:0.698456
# [6]	validation_0-auc:0.72804	validation_1-auc:0.705493
# [7]	validation_0-auc:0.737078	validation_1-auc:0.713525
# [8]	validation_0-auc:0.763683	validation_1-auc:0.735933
# [9]	validation_0-auc:0.769851	validation_1-auc:0.739039
# [10]	validation_0-auc:0.771843	validation_1-auc:0.742474
# [11]	validation_0-auc:0.775271	validation_1-auc:0.74265
# [12]	validation_0-auc:0.774219	validation_1-auc:0.741578
# [13]	validation_0-auc:0.776724	validation_1-auc:0.743128
# [14]	validation_0-auc:0.780153	validation_1-auc:0.746155
# [15]	validation_0-auc:0.781333	validation_1-auc:0.747964
# [16]	validation_0-auc:0.781491	validation_1-auc:0.746861
# [17]	validation_0-auc:0.784016	validation_1-auc:0.745789
# [18]	validation_0-auc:0.79063	validation_1-auc:0.751948
# [19]	validation_0-auc:0.790161	validation_1-auc:0.752444
# [20]	validation_0-auc:0.796141	validation_1-auc:0.759196
# [21]	validation_0-auc:0.804278	validation_1-auc:0.763467
# [22]	validation_0-auc:0.803281	validation_1-auc:0.762153
# [23]	validation_0-auc:0.803688	validation_1-auc:0.762047
# [24]	validation_0-auc:0.804088	validation_1-auc:0.762127
# [25]	validation_0-auc:0.804088	validation_1-auc:0.762127
# [26]	validation_0-auc:0.809092	validation_1-auc:0.764385
# [27]	validation_0-auc:0.81088	validation_1-auc:0.768046
# [28]	validation_0-auc:0.810797	validation_1-auc:0.769778
# [29]	validation_0-auc:0.814027	validation_1-auc:0.770897
# [30]	validation_0-auc:0.814027	validation_1-auc:0.770897
# [31]	validation_0-auc:0.813302	validation_1-auc:0.770803
# [32]	validation_0-auc:0.814632	validation_1-auc:0.770167
# [33]	validation_0-auc:0.816246	validation_1-auc:0.772508
# [34]	validation_0-auc:0.816246	validation_1-auc:0.772508
# [35]	validation_0-auc:0.816246	validation_1-auc:0.772508
# [36]	validation_0-auc:0.816246	validation_1-auc:0.772508
# [37]	validation_0-auc:0.816246	validation_1-auc:0.772508
# [38]	validation_0-auc:0.819217	validation_1-auc:0.774187
# [39]	validation_0-auc:0.820882	validation_1-auc:0.774496
# [40]	validation_0-auc:0.820882	validation_1-auc:0.774496
# [41]	validation_0-auc:0.820882	validation_1-auc:0.774496
# [42]	validation_0-auc:0.820882	validation_1-auc:0.774496
# [43]	validation_0-auc:0.820882	validation_1-auc:0.774496
# [44]	validation_0-auc:0.820882	validation_1-auc:0.774496
# [45]	validation_0-auc:0.822238	validation_1-auc:0.775627
# [46]	validation_0-auc:0.822238	validation_1-auc:0.775627
# [47]	validation_0-auc:0.822238	validation_1-auc:0.775627
# [48]	validation_0-auc:0.822238	validation_1-auc:0.775627
# [49]	validation_0-auc:0.822238	validation_1-auc:0.775627
# [50]	validation_0-auc:0.822238	validation_1-auc:0.775627
# [51]	validation_0-auc:0.824144	validation_1-auc:0.778727
# [52]	validation_0-auc:0.824144	validation_1-auc:0.778727
# [53]	validation_0-auc:0.824144	validation_1-auc:0.778727
# [54]	validation_0-auc:0.824144	validation_1-auc:0.778727
# [55]	validation_0-auc:0.824026	validation_1-auc:0.778992
# [56]	validation_0-auc:0.824026	validation_1-auc:0.778992
# [57]	validation_0-auc:0.825149	validation_1-auc:0.779062
# [58]	validation_0-auc:0.825149	validation_1-auc:0.779062
# [59]	validation_0-auc:0.825149	validation_1-auc:0.779062
# [0]	validation_0-auc:0.708835	validation_1-auc:0.685422
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.71661	validation_1-auc:0.692325
# [2]	validation_0-auc:0.719463	validation_1-auc:0.698837
# [3]	validation_0-auc:0.728038	validation_1-auc:0.708651
# [4]	validation_0-auc:0.734763	validation_1-auc:0.712959
# [5]	validation_0-auc:0.73526	validation_1-auc:0.71219
# [6]	validation_0-auc:0.74204	validation_1-auc:0.718678
# [7]	validation_0-auc:0.741642	validation_1-auc:0.719283
# [8]	validation_0-auc:0.744982	validation_1-auc:0.719812
# [9]	validation_0-auc:0.745871	validation_1-auc:0.720418
# [10]	validation_0-auc:0.758416	validation_1-auc:0.726766
# [11]	validation_0-auc:0.756615	validation_1-auc:0.727788
# [12]	validation_0-auc:0.756216	validation_1-auc:0.727069
# [13]	validation_0-auc:0.757099	validation_1-auc:0.727994
# [14]	validation_0-auc:0.757819	validation_1-auc:0.729343
# [15]	validation_0-auc:0.759259	validation_1-auc:0.730792
# [16]	validation_0-auc:0.761289	validation_1-auc:0.730126
# [17]	validation_0-auc:0.762541	validation_1-auc:0.730722
# [18]	validation_0-auc:0.768412	validation_1-auc:0.733056
# [19]	validation_0-auc:0.766652	validation_1-auc:0.731571
# [20]	validation_0-auc:0.776384	validation_1-auc:0.741546
# [21]	validation_0-auc:0.776015	validation_1-auc:0.743929
# [22]	validation_0-auc:0.779321	validation_1-auc:0.744006
# [23]	validation_0-auc:0.780597	validation_1-auc:0.744365
# [24]	validation_0-auc:0.779411	validation_1-auc:0.74321
# [25]	validation_0-auc:0.784248	validation_1-auc:0.750058
# [26]	validation_0-auc:0.787226	validation_1-auc:0.750851
# [27]	validation_0-auc:0.78881	validation_1-auc:0.749883
# [28]	validation_0-auc:0.792031	validation_1-auc:0.753009
# [29]	validation_0-auc:0.794402	validation_1-auc:0.755613
# [30]	validation_0-auc:0.794402	validation_1-auc:0.755613
# [31]	validation_0-auc:0.794402	validation_1-auc:0.755613
# [32]	validation_0-auc:0.794402	validation_1-auc:0.755613
# [33]	validation_0-auc:0.794402	validation_1-auc:0.755613
# [34]	validation_0-auc:0.794402	validation_1-auc:0.755613
# [35]	validation_0-auc:0.793316	validation_1-auc:0.7548
# [36]	validation_0-auc:0.793316	validation_1-auc:0.7548
# [37]	validation_0-auc:0.793316	validation_1-auc:0.7548
# [38]	validation_0-auc:0.795997	validation_1-auc:0.760835
# [39]	validation_0-auc:0.795997	validation_1-auc:0.760835
# [40]	validation_0-auc:0.795997	validation_1-auc:0.760835
# [41]	validation_0-auc:0.798312	validation_1-auc:0.763665
# [42]	validation_0-auc:0.798312	validation_1-auc:0.763665
# [43]	validation_0-auc:0.798312	validation_1-auc:0.763665
# [44]	validation_0-auc:0.798312	validation_1-auc:0.763665
# [45]	validation_0-auc:0.799393	validation_1-auc:0.764275
# [46]	validation_0-auc:0.799393	validation_1-auc:0.764275
# [47]	validation_0-auc:0.801027	validation_1-auc:0.76604
# [48]	validation_0-auc:0.801027	validation_1-auc:0.76604
# [49]	validation_0-auc:0.801027	validation_1-auc:0.76604
# [50]	validation_0-auc:0.801027	validation_1-auc:0.76604
# [51]	validation_0-auc:0.802572	validation_1-auc:0.767215
# [52]	validation_0-auc:0.802572	validation_1-auc:0.767215
# [53]	validation_0-auc:0.802572	validation_1-auc:0.767215
# [54]	validation_0-auc:0.806348	validation_1-auc:0.769851
# [55]	validation_0-auc:0.806348	validation_1-auc:0.769851
# [56]	validation_0-auc:0.810746	validation_1-auc:0.773439
# [57]	validation_0-auc:0.810746	validation_1-auc:0.773439
# [58]	validation_0-auc:0.810746	validation_1-auc:0.773439
# [59]	validation_0-auc:0.812877	validation_1-auc:0.774258
# [0]	validation_0-auc:0.720682	validation_1-auc:0.69832
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.724003	validation_1-auc:0.704652
# [2]	validation_0-auc:0.760901	validation_1-auc:0.737853
# [3]	validation_0-auc:0.763914	validation_1-auc:0.736478
# [4]	validation_0-auc:0.772501	validation_1-auc:0.744632
# [5]	validation_0-auc:0.774773	validation_1-auc:0.747139
# [6]	validation_0-auc:0.790808	validation_1-auc:0.754954
# [7]	validation_0-auc:0.796505	validation_1-auc:0.75696
# [8]	validation_0-auc:0.800382	validation_1-auc:0.76014
# [9]	validation_0-auc:0.800074	validation_1-auc:0.758961
# [10]	validation_0-auc:0.814312	validation_1-auc:0.771649
# [11]	validation_0-auc:0.81386	validation_1-auc:0.770544
# [12]	validation_0-auc:0.8144	validation_1-auc:0.771523
# [13]	validation_0-auc:0.815382	validation_1-auc:0.772217
# [14]	validation_0-auc:0.824139	validation_1-auc:0.783313
# [15]	validation_0-auc:0.82459	validation_1-auc:0.783568
# [16]	validation_0-auc:0.83105	validation_1-auc:0.792837
# [17]	validation_0-auc:0.83105	validation_1-auc:0.792837
# [18]	validation_0-auc:0.835148	validation_1-auc:0.795693
# [19]	validation_0-auc:0.835148	validation_1-auc:0.795693
# [20]	validation_0-auc:0.835148	validation_1-auc:0.795693
# [21]	validation_0-auc:0.833688	validation_1-auc:0.794254
# [22]	validation_0-auc:0.833688	validation_1-auc:0.794254
# [23]	validation_0-auc:0.83514	validation_1-auc:0.795406
# [24]	validation_0-auc:0.83514	validation_1-auc:0.795406
# [25]	validation_0-auc:0.83514	validation_1-auc:0.795406
# [26]	validation_0-auc:0.837056	validation_1-auc:0.79644
# [27]	validation_0-auc:0.839675	validation_1-auc:0.799043
# [28]	validation_0-auc:0.839675	validation_1-auc:0.799043
# [29]	validation_0-auc:0.839675	validation_1-auc:0.799043
# [30]	validation_0-auc:0.839675	validation_1-auc:0.799043
# [31]	validation_0-auc:0.839864	validation_1-auc:0.799756
# [32]	validation_0-auc:0.839864	validation_1-auc:0.799756
# [33]	validation_0-auc:0.839864	validation_1-auc:0.799756
# [34]	validation_0-auc:0.839864	validation_1-auc:0.799756
# [35]	validation_0-auc:0.839864	validation_1-auc:0.799756
# [36]	validation_0-auc:0.839864	validation_1-auc:0.799756
# [37]	validation_0-auc:0.839864	validation_1-auc:0.799756
# [38]	validation_0-auc:0.839864	validation_1-auc:0.799756
# [39]	validation_0-auc:0.839864	validation_1-auc:0.799756
# [40]	validation_0-auc:0.839864	validation_1-auc:0.799756
# [41]	validation_0-auc:0.839864	validation_1-auc:0.799756
# Stopping. Best iteration:
# [31]	validation_0-auc:0.839864	validation_1-auc:0.799756
#
# [0]	validation_0-auc:0.715381	validation_1-auc:0.666653
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.748119	validation_1-auc:0.709739
# [2]	validation_0-auc:0.759578	validation_1-auc:0.723149
# [3]	validation_0-auc:0.761245	validation_1-auc:0.724393
# [4]	validation_0-auc:0.763511	validation_1-auc:0.729844
# [5]	validation_0-auc:0.766312	validation_1-auc:0.735745
# [6]	validation_0-auc:0.763785	validation_1-auc:0.731238
# [7]	validation_0-auc:0.801913	validation_1-auc:0.760189
# [8]	validation_0-auc:0.807719	validation_1-auc:0.765272
# [9]	validation_0-auc:0.80485	validation_1-auc:0.762938
# [10]	validation_0-auc:0.818367	validation_1-auc:0.77583
# [11]	validation_0-auc:0.815632	validation_1-auc:0.774503
# [12]	validation_0-auc:0.814984	validation_1-auc:0.775396
# [13]	validation_0-auc:0.817526	validation_1-auc:0.776589
# [14]	validation_0-auc:0.815465	validation_1-auc:0.772978
# [15]	validation_0-auc:0.818499	validation_1-auc:0.775938
# [16]	validation_0-auc:0.819998	validation_1-auc:0.776435
# [17]	validation_0-auc:0.819998	validation_1-auc:0.776435
# [18]	validation_0-auc:0.820425	validation_1-auc:0.775755
# [19]	validation_0-auc:0.820425	validation_1-auc:0.775755
# [20]	validation_0-auc:0.820425	validation_1-auc:0.775755
# [21]	validation_0-auc:0.820425	validation_1-auc:0.775755
# [22]	validation_0-auc:0.820425	validation_1-auc:0.775755
# [23]	validation_0-auc:0.820425	validation_1-auc:0.775755
# Stopping. Best iteration:
# [13]	validation_0-auc:0.817526	validation_1-auc:0.776589
#
# [0]	validation_0-auc:0.721408	validation_1-auc:0.702749
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.724358	validation_1-auc:0.709662
# [2]	validation_0-auc:0.760863	validation_1-auc:0.739069
# [3]	validation_0-auc:0.762599	validation_1-auc:0.739705
# [4]	validation_0-auc:0.771442	validation_1-auc:0.748693
# [5]	validation_0-auc:0.776064	validation_1-auc:0.752699
# [6]	validation_0-auc:0.800375	validation_1-auc:0.777091
# [7]	validation_0-auc:0.812404	validation_1-auc:0.788691
# [8]	validation_0-auc:0.812991	validation_1-auc:0.787526
# [9]	validation_0-auc:0.814094	validation_1-auc:0.787977
# [10]	validation_0-auc:0.813928	validation_1-auc:0.788045
# [11]	validation_0-auc:0.815541	validation_1-auc:0.789306
# [12]	validation_0-auc:0.819514	validation_1-auc:0.791777
# [13]	validation_0-auc:0.821644	validation_1-auc:0.793395
# [14]	validation_0-auc:0.822884	validation_1-auc:0.794437
# [15]	validation_0-auc:0.82668	validation_1-auc:0.79728
# [16]	validation_0-auc:0.826939	validation_1-auc:0.796036
# [17]	validation_0-auc:0.828922	validation_1-auc:0.797621
# [18]	validation_0-auc:0.828922	validation_1-auc:0.797621
# [19]	validation_0-auc:0.828922	validation_1-auc:0.797621
# [20]	validation_0-auc:0.828922	validation_1-auc:0.797621
# [21]	validation_0-auc:0.828922	validation_1-auc:0.797621
# [22]	validation_0-auc:0.828922	validation_1-auc:0.797621
# [23]	validation_0-auc:0.828474	validation_1-auc:0.797608
# [24]	validation_0-auc:0.828474	validation_1-auc:0.797608
# [25]	validation_0-auc:0.828474	validation_1-auc:0.797608
# [26]	validation_0-auc:0.828538	validation_1-auc:0.79675
# [27]	validation_0-auc:0.828538	validation_1-auc:0.79675
# Stopping. Best iteration:
# [17]	validation_0-auc:0.828922	validation_1-auc:0.797621
#
# [0]	validation_0-auc:0.70649	validation_1-auc:0.686474
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.737151	validation_1-auc:0.712291
# [2]	validation_0-auc:0.742887	validation_1-auc:0.71493
# [3]	validation_0-auc:0.748613	validation_1-auc:0.7218
# [4]	validation_0-auc:0.7487	validation_1-auc:0.721273
# [5]	validation_0-auc:0.779166	validation_1-auc:0.746255
# [6]	validation_0-auc:0.779348	validation_1-auc:0.746199
# [7]	validation_0-auc:0.783526	validation_1-auc:0.752608
# [8]	validation_0-auc:0.786811	validation_1-auc:0.75506
# [9]	validation_0-auc:0.789684	validation_1-auc:0.756657
# [10]	validation_0-auc:0.789433	validation_1-auc:0.755057
# [11]	validation_0-auc:0.7894	validation_1-auc:0.754709
# [12]	validation_0-auc:0.789771	validation_1-auc:0.75495
# [13]	validation_0-auc:0.791367	validation_1-auc:0.756324
# [14]	validation_0-auc:0.792775	validation_1-auc:0.755938
# [15]	validation_0-auc:0.799904	validation_1-auc:0.760102
# [16]	validation_0-auc:0.799904	validation_1-auc:0.760102
# [17]	validation_0-auc:0.799904	validation_1-auc:0.760102
# [18]	validation_0-auc:0.799593	validation_1-auc:0.760557
# [19]	validation_0-auc:0.799593	validation_1-auc:0.760557
# [20]	validation_0-auc:0.812468	validation_1-auc:0.774776
# [21]	validation_0-auc:0.812468	validation_1-auc:0.774776
# [22]	validation_0-auc:0.815393	validation_1-auc:0.776525
# [23]	validation_0-auc:0.815393	validation_1-auc:0.776525
# [24]	validation_0-auc:0.814668	validation_1-auc:0.77559
# [25]	validation_0-auc:0.817775	validation_1-auc:0.777961
# [26]	validation_0-auc:0.817775	validation_1-auc:0.777961
# [27]	validation_0-auc:0.817775	validation_1-auc:0.777961
# [28]	validation_0-auc:0.816958	validation_1-auc:0.778408
# [29]	validation_0-auc:0.816958	validation_1-auc:0.778408
# [30]	validation_0-auc:0.816958	validation_1-auc:0.778408
# [31]	validation_0-auc:0.816446	validation_1-auc:0.77777
# [32]	validation_0-auc:0.816446	validation_1-auc:0.77777
# [33]	validation_0-auc:0.816446	validation_1-auc:0.77777
# [34]	validation_0-auc:0.816446	validation_1-auc:0.77777
# [35]	validation_0-auc:0.816446	validation_1-auc:0.77777
# [36]	validation_0-auc:0.822656	validation_1-auc:0.782474
# [37]	validation_0-auc:0.822656	validation_1-auc:0.782474
# [38]	validation_0-auc:0.822656	validation_1-auc:0.782474
# [39]	validation_0-auc:0.822656	validation_1-auc:0.782474
# [40]	validation_0-auc:0.822656	validation_1-auc:0.782474
# [41]	validation_0-auc:0.822656	validation_1-auc:0.782474
# [42]	validation_0-auc:0.822656	validation_1-auc:0.782474
# [43]	validation_0-auc:0.822656	validation_1-auc:0.782474
# [44]	validation_0-auc:0.822656	validation_1-auc:0.782474
# [45]	validation_0-auc:0.822656	validation_1-auc:0.782474
# [46]	validation_0-auc:0.822656	validation_1-auc:0.782474
# Stopping. Best iteration:
# [36]	validation_0-auc:0.822656	validation_1-auc:0.782474
#
# [0]	validation_0-auc:0.711608	validation_1-auc:0.686218
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.742788	validation_1-auc:0.706242
# [2]	validation_0-auc:0.770209	validation_1-auc:0.728626
# [3]	validation_0-auc:0.773854	validation_1-auc:0.732239
# [4]	validation_0-auc:0.779206	validation_1-auc:0.740524
# [5]	validation_0-auc:0.787523	validation_1-auc:0.749133
# [6]	validation_0-auc:0.803816	validation_1-auc:0.761426
# [7]	validation_0-auc:0.807655	validation_1-auc:0.764198
# [8]	validation_0-auc:0.807655	validation_1-auc:0.764198
# [9]	validation_0-auc:0.80747	validation_1-auc:0.765433
# [10]	validation_0-auc:0.808885	validation_1-auc:0.766529
# [11]	validation_0-auc:0.808885	validation_1-auc:0.766529
# [12]	validation_0-auc:0.808885	validation_1-auc:0.766529
# [13]	validation_0-auc:0.808885	validation_1-auc:0.766529
# [14]	validation_0-auc:0.808885	validation_1-auc:0.766529
# [15]	validation_0-auc:0.808885	validation_1-auc:0.766529
# [16]	validation_0-auc:0.808885	validation_1-auc:0.766529
# [17]	validation_0-auc:0.808885	validation_1-auc:0.766529
# [18]	validation_0-auc:0.808885	validation_1-auc:0.766529
# [19]	validation_0-auc:0.808885	validation_1-auc:0.766529
# [20]	validation_0-auc:0.808885	validation_1-auc:0.766529
# Stopping. Best iteration:
# [10]	validation_0-auc:0.808885	validation_1-auc:0.766529
#
# [0]	validation_0-auc:0.698321	validation_1-auc:0.647891
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.736327	validation_1-auc:0.690993
# [2]	validation_0-auc:0.760624	validation_1-auc:0.720402
# [3]	validation_0-auc:0.766118	validation_1-auc:0.727978
# [4]	validation_0-auc:0.795941	validation_1-auc:0.755078
# [5]	validation_0-auc:0.795019	validation_1-auc:0.75371
# [6]	validation_0-auc:0.797087	validation_1-auc:0.756049
# [7]	validation_0-auc:0.812218	validation_1-auc:0.767247
# [8]	validation_0-auc:0.819463	validation_1-auc:0.772831
# [9]	validation_0-auc:0.819463	validation_1-auc:0.772831
# [10]	validation_0-auc:0.821647	validation_1-auc:0.775422
# [11]	validation_0-auc:0.821647	validation_1-auc:0.775422
# [12]	validation_0-auc:0.821647	validation_1-auc:0.775422
# [13]	validation_0-auc:0.821647	validation_1-auc:0.775422
# [14]	validation_0-auc:0.821647	validation_1-auc:0.775422
# [15]	validation_0-auc:0.821647	validation_1-auc:0.775422
# [16]	validation_0-auc:0.821647	validation_1-auc:0.775422
# [17]	validation_0-auc:0.821647	validation_1-auc:0.775422
# [18]	validation_0-auc:0.821647	validation_1-auc:0.775422
# [19]	validation_0-auc:0.821647	validation_1-auc:0.775422
# [20]	validation_0-auc:0.821647	validation_1-auc:0.775422
# Stopping. Best iteration:
# [10]	validation_0-auc:0.821647	validation_1-auc:0.775422
#
# [0]	validation_0-auc:0.703877	validation_1-auc:0.692112
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.747672	validation_1-auc:0.719952
# [2]	validation_0-auc:0.755535	validation_1-auc:0.725355
# [3]	validation_0-auc:0.800333	validation_1-auc:0.764241
# [4]	validation_0-auc:0.803501	validation_1-auc:0.767402
# [5]	validation_0-auc:0.81081	validation_1-auc:0.777264
# [6]	validation_0-auc:0.819895	validation_1-auc:0.783181
# [7]	validation_0-auc:0.823515	validation_1-auc:0.786089
# [8]	validation_0-auc:0.823515	validation_1-auc:0.786089
# [9]	validation_0-auc:0.823515	validation_1-auc:0.786089
# [10]	validation_0-auc:0.832588	validation_1-auc:0.795541
# [11]	validation_0-auc:0.833795	validation_1-auc:0.799198
# [12]	validation_0-auc:0.833795	validation_1-auc:0.799198
# [13]	validation_0-auc:0.833795	validation_1-auc:0.799198
# [14]	validation_0-auc:0.833795	validation_1-auc:0.799198
# [15]	validation_0-auc:0.833795	validation_1-auc:0.799198
# [16]	validation_0-auc:0.833795	validation_1-auc:0.799198
# [17]	validation_0-auc:0.833795	validation_1-auc:0.799198
# [18]	validation_0-auc:0.833795	validation_1-auc:0.799198
# [19]	validation_0-auc:0.833795	validation_1-auc:0.799198
# [20]	validation_0-auc:0.833795	validation_1-auc:0.799198
# [21]	validation_0-auc:0.833795	validation_1-auc:0.799198
# Stopping. Best iteration:
# [11]	validation_0-auc:0.833795	validation_1-auc:0.799198
#
# [0]	validation_0-auc:0.701337	validation_1-auc:0.68387
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.727323	validation_1-auc:0.699817
# [2]	validation_0-auc:0.735983	validation_1-auc:0.712576
# [3]	validation_0-auc:0.750822	validation_1-auc:0.722045
# [4]	validation_0-auc:0.762846	validation_1-auc:0.727197
# [5]	validation_0-auc:0.779216	validation_1-auc:0.736033
# [6]	validation_0-auc:0.786995	validation_1-auc:0.746217
# [7]	validation_0-auc:0.789047	validation_1-auc:0.746179
# [8]	validation_0-auc:0.790374	validation_1-auc:0.746815
# [9]	validation_0-auc:0.790374	validation_1-auc:0.746815
# [10]	validation_0-auc:0.790374	validation_1-auc:0.746815
# [11]	validation_0-auc:0.791077	validation_1-auc:0.749339
# [12]	validation_0-auc:0.791077	validation_1-auc:0.749339
# [13]	validation_0-auc:0.791077	validation_1-auc:0.749339
# [14]	validation_0-auc:0.791077	validation_1-auc:0.749339
# [15]	validation_0-auc:0.791077	validation_1-auc:0.749339
# [16]	validation_0-auc:0.791077	validation_1-auc:0.749339
# [17]	validation_0-auc:0.791077	validation_1-auc:0.749339
# [18]	validation_0-auc:0.791077	validation_1-auc:0.749339
# [19]	validation_0-auc:0.791077	validation_1-auc:0.749339
# [20]	validation_0-auc:0.791077	validation_1-auc:0.749339
# [21]	validation_0-auc:0.791077	validation_1-auc:0.749339
# Stopping. Best iteration:
# [11]	validation_0-auc:0.791077	validation_1-auc:0.749339
#
# [0]	validation_0-auc:0.654125	validation_1-auc:0.649187
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.704394	validation_1-auc:0.690908
# [2]	validation_0-auc:0.71061	validation_1-auc:0.687577
# [3]	validation_0-auc:0.726777	validation_1-auc:0.698075
# [4]	validation_0-auc:0.73851	validation_1-auc:0.705116
# [5]	validation_0-auc:0.73394	validation_1-auc:0.697404
# [6]	validation_0-auc:0.738981	validation_1-auc:0.704164
# [7]	validation_0-auc:0.742314	validation_1-auc:0.702929
# [8]	validation_0-auc:0.750801	validation_1-auc:0.708275
# [9]	validation_0-auc:0.75168	validation_1-auc:0.708348
# [10]	validation_0-auc:0.752691	validation_1-auc:0.712524
# [11]	validation_0-auc:0.75168	validation_1-auc:0.715343
# [12]	validation_0-auc:0.757586	validation_1-auc:0.720765
# [13]	validation_0-auc:0.757923	validation_1-auc:0.71999
# [14]	validation_0-auc:0.762054	validation_1-auc:0.721622
# [15]	validation_0-auc:0.761676	validation_1-auc:0.72044
# [16]	validation_0-auc:0.765189	validation_1-auc:0.723216
# [17]	validation_0-auc:0.764233	validation_1-auc:0.72555
# [18]	validation_0-auc:0.767085	validation_1-auc:0.727545
# [19]	validation_0-auc:0.768718	validation_1-auc:0.729536
# [20]	validation_0-auc:0.772263	validation_1-auc:0.731403
# [21]	validation_0-auc:0.772173	validation_1-auc:0.732402
# [22]	validation_0-auc:0.774584	validation_1-auc:0.734567
# [23]	validation_0-auc:0.776121	validation_1-auc:0.73439
# [24]	validation_0-auc:0.779616	validation_1-auc:0.738356
# [25]	validation_0-auc:0.781865	validation_1-auc:0.740534
# [26]	validation_0-auc:0.785241	validation_1-auc:0.742779
# [0]	validation_0-auc:0.653977	validation_1-auc:0.616475
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.653977	validation_1-auc:0.616475
# [2]	validation_0-auc:0.701918	validation_1-auc:0.657808
# [3]	validation_0-auc:0.704774	validation_1-auc:0.667219
# [4]	validation_0-auc:0.71625	validation_1-auc:0.679126
# [5]	validation_0-auc:0.728165	validation_1-auc:0.688234
# [6]	validation_0-auc:0.735369	validation_1-auc:0.695466
# [7]	validation_0-auc:0.736554	validation_1-auc:0.696868
# [8]	validation_0-auc:0.740317	validation_1-auc:0.700781
# [9]	validation_0-auc:0.743998	validation_1-auc:0.70266
# [10]	validation_0-auc:0.745402	validation_1-auc:0.702171
# [11]	validation_0-auc:0.749506	validation_1-auc:0.70655
# [12]	validation_0-auc:0.749152	validation_1-auc:0.706965
# [13]	validation_0-auc:0.753696	validation_1-auc:0.707789
# [14]	validation_0-auc:0.754971	validation_1-auc:0.708107
# [15]	validation_0-auc:0.759168	validation_1-auc:0.71046
# [16]	validation_0-auc:0.762415	validation_1-auc:0.711539
# [17]	validation_0-auc:0.761282	validation_1-auc:0.713254
# [18]	validation_0-auc:0.764873	validation_1-auc:0.715808
# [19]	validation_0-auc:0.768314	validation_1-auc:0.719574
# [20]	validation_0-auc:0.76698	validation_1-auc:0.719721
# [21]	validation_0-auc:0.766871	validation_1-auc:0.721414
# [22]	validation_0-auc:0.768629	validation_1-auc:0.722934
# [23]	validation_0-auc:0.771773	validation_1-auc:0.725668
# [24]	validation_0-auc:0.77571	validation_1-auc:0.727597
# [25]	validation_0-auc:0.775803	validation_1-auc:0.726488
# [26]	validation_0-auc:0.77911	validation_1-auc:0.730585
# [0]	validation_0-auc:0.706564	validation_1-auc:0.690417
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.706215	validation_1-auc:0.69048
# [2]	validation_0-auc:0.728976	validation_1-auc:0.708503
# [3]	validation_0-auc:0.728976	validation_1-auc:0.708503
# [4]	validation_0-auc:0.738751	validation_1-auc:0.715257
# [5]	validation_0-auc:0.7512	validation_1-auc:0.727412
# [6]	validation_0-auc:0.75691	validation_1-auc:0.731236
# [7]	validation_0-auc:0.753094	validation_1-auc:0.729951
# [8]	validation_0-auc:0.761556	validation_1-auc:0.73466
# [9]	validation_0-auc:0.761256	validation_1-auc:0.735349
# [10]	validation_0-auc:0.762058	validation_1-auc:0.732708
# [11]	validation_0-auc:0.759134	validation_1-auc:0.732732
# [12]	validation_0-auc:0.766686	validation_1-auc:0.738556
# [13]	validation_0-auc:0.768252	validation_1-auc:0.737019
# [14]	validation_0-auc:0.771114	validation_1-auc:0.739037
# [15]	validation_0-auc:0.772183	validation_1-auc:0.742585
# [16]	validation_0-auc:0.775319	validation_1-auc:0.744104
# [17]	validation_0-auc:0.776796	validation_1-auc:0.746906
# [18]	validation_0-auc:0.780505	validation_1-auc:0.748511
# [19]	validation_0-auc:0.783302	validation_1-auc:0.751389
# [20]	validation_0-auc:0.786738	validation_1-auc:0.753503
# [21]	validation_0-auc:0.789422	validation_1-auc:0.754186
# [22]	validation_0-auc:0.789511	validation_1-auc:0.757193
# [23]	validation_0-auc:0.789173	validation_1-auc:0.755899
# [24]	validation_0-auc:0.792563	validation_1-auc:0.757078
# [25]	validation_0-auc:0.79193	validation_1-auc:0.756807
# [26]	validation_0-auc:0.795621	validation_1-auc:0.759448
# [0]	validation_0-auc:0.701142	validation_1-auc:0.67374
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.708265	validation_1-auc:0.683224
# [2]	validation_0-auc:0.729956	validation_1-auc:0.699593
# [3]	validation_0-auc:0.729495	validation_1-auc:0.699344
# [4]	validation_0-auc:0.737721	validation_1-auc:0.706255
# [5]	validation_0-auc:0.738099	validation_1-auc:0.70623
# [6]	validation_0-auc:0.739423	validation_1-auc:0.706913
# [7]	validation_0-auc:0.743023	validation_1-auc:0.716545
# [8]	validation_0-auc:0.742963	validation_1-auc:0.716063
# [9]	validation_0-auc:0.752206	validation_1-auc:0.72257
# [10]	validation_0-auc:0.74937	validation_1-auc:0.721411
# [11]	validation_0-auc:0.7548	validation_1-auc:0.726363
# [12]	validation_0-auc:0.758657	validation_1-auc:0.728143
# [13]	validation_0-auc:0.757035	validation_1-auc:0.726304
# [14]	validation_0-auc:0.763558	validation_1-auc:0.732096
# [15]	validation_0-auc:0.76397	validation_1-auc:0.731862
# [16]	validation_0-auc:0.763398	validation_1-auc:0.731363
# [17]	validation_0-auc:0.768677	validation_1-auc:0.73457
# [18]	validation_0-auc:0.767648	validation_1-auc:0.734522
# [19]	validation_0-auc:0.768145	validation_1-auc:0.733752
# [20]	validation_0-auc:0.772983	validation_1-auc:0.737678
# [21]	validation_0-auc:0.776386	validation_1-auc:0.738348
# [22]	validation_0-auc:0.775246	validation_1-auc:0.740406
# [23]	validation_0-auc:0.779206	validation_1-auc:0.743465
# [24]	validation_0-auc:0.779724	validation_1-auc:0.744818
# [25]	validation_0-auc:0.7781	validation_1-auc:0.744514
# [26]	validation_0-auc:0.778709	validation_1-auc:0.746254
# [0]	validation_0-auc:0.679272	validation_1-auc:0.646609
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.734242	validation_1-auc:0.705248
# [2]	validation_0-auc:0.733068	validation_1-auc:0.705892
# [3]	validation_0-auc:0.739144	validation_1-auc:0.711778
# [4]	validation_0-auc:0.739144	validation_1-auc:0.711778
# [5]	validation_0-auc:0.739144	validation_1-auc:0.711778
# [6]	validation_0-auc:0.739144	validation_1-auc:0.711778
# [7]	validation_0-auc:0.739144	validation_1-auc:0.711778
# [8]	validation_0-auc:0.739144	validation_1-auc:0.711778
# [9]	validation_0-auc:0.739144	validation_1-auc:0.711778
# [10]	validation_0-auc:0.739144	validation_1-auc:0.711778
# [11]	validation_0-auc:0.746003	validation_1-auc:0.722814
# [12]	validation_0-auc:0.746003	validation_1-auc:0.722814
# [13]	validation_0-auc:0.746003	validation_1-auc:0.722814
# [14]	validation_0-auc:0.763914	validation_1-auc:0.746169
# [15]	validation_0-auc:0.763914	validation_1-auc:0.746169
# [16]	validation_0-auc:0.763914	validation_1-auc:0.746169
# [17]	validation_0-auc:0.763914	validation_1-auc:0.746169
# [18]	validation_0-auc:0.763914	validation_1-auc:0.746169
# [19]	validation_0-auc:0.763914	validation_1-auc:0.746169
# [20]	validation_0-auc:0.763914	validation_1-auc:0.746169
# [21]	validation_0-auc:0.763914	validation_1-auc:0.746169
# [22]	validation_0-auc:0.763914	validation_1-auc:0.746169
# [23]	validation_0-auc:0.763914	validation_1-auc:0.746169
# [24]	validation_0-auc:0.763914	validation_1-auc:0.746169
# Stopping. Best iteration:
# [14]	validation_0-auc:0.763914	validation_1-auc:0.746169
#
# [0]	validation_0-auc:0.698509	validation_1-auc:0.684996
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.697034	validation_1-auc:0.688086
# [2]	validation_0-auc:0.697034	validation_1-auc:0.688086
# [3]	validation_0-auc:0.738643	validation_1-auc:0.716459
# [4]	validation_0-auc:0.738643	validation_1-auc:0.716459
# [5]	validation_0-auc:0.741338	validation_1-auc:0.720522
# [6]	validation_0-auc:0.741338	validation_1-auc:0.720522
# [7]	validation_0-auc:0.741338	validation_1-auc:0.720522
# [8]	validation_0-auc:0.741338	validation_1-auc:0.720522
# [9]	validation_0-auc:0.741338	validation_1-auc:0.720522
# [10]	validation_0-auc:0.741338	validation_1-auc:0.720522
# [11]	validation_0-auc:0.741338	validation_1-auc:0.720522
# [12]	validation_0-auc:0.740241	validation_1-auc:0.722934
# [13]	validation_0-auc:0.740241	validation_1-auc:0.722934
# [14]	validation_0-auc:0.740241	validation_1-auc:0.722934
# [15]	validation_0-auc:0.740241	validation_1-auc:0.722934
# [16]	validation_0-auc:0.740241	validation_1-auc:0.722934
# [17]	validation_0-auc:0.740241	validation_1-auc:0.722934
# [18]	validation_0-auc:0.740241	validation_1-auc:0.722934
# [19]	validation_0-auc:0.740241	validation_1-auc:0.722934
# [20]	validation_0-auc:0.740241	validation_1-auc:0.722934
# [21]	validation_0-auc:0.740241	validation_1-auc:0.722934
# [22]	validation_0-auc:0.740241	validation_1-auc:0.722934
# Stopping. Best iteration:
# [12]	validation_0-auc:0.740241	validation_1-auc:0.722934
#
# [0]	validation_0-auc:0.698255	validation_1-auc:0.690087
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.699373	validation_1-auc:0.695048
# [2]	validation_0-auc:0.699373	validation_1-auc:0.695048
# [3]	validation_0-auc:0.702816	validation_1-auc:0.693832
# [4]	validation_0-auc:0.722032	validation_1-auc:0.710197
# [5]	validation_0-auc:0.728101	validation_1-auc:0.712466
# [6]	validation_0-auc:0.728101	validation_1-auc:0.712466
# [7]	validation_0-auc:0.728101	validation_1-auc:0.712466
# [8]	validation_0-auc:0.728101	validation_1-auc:0.712466
# [9]	validation_0-auc:0.728101	validation_1-auc:0.712466
# [10]	validation_0-auc:0.728101	validation_1-auc:0.712466
# [11]	validation_0-auc:0.728101	validation_1-auc:0.712466
# [12]	validation_0-auc:0.728101	validation_1-auc:0.712443
# [13]	validation_0-auc:0.728101	validation_1-auc:0.712443
# [14]	validation_0-auc:0.728101	validation_1-auc:0.712443
# [15]	validation_0-auc:0.728101	validation_1-auc:0.712443
# Stopping. Best iteration:
# [5]	validation_0-auc:0.728101	validation_1-auc:0.712466
#
# [0]	validation_0-auc:0.700504	validation_1-auc:0.682102
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.708015	validation_1-auc:0.692049
# [2]	validation_0-auc:0.723926	validation_1-auc:0.704812
# [3]	validation_0-auc:0.727001	validation_1-auc:0.710751
# [4]	validation_0-auc:0.727001	validation_1-auc:0.710751
# [5]	validation_0-auc:0.727001	validation_1-auc:0.710751
# [6]	validation_0-auc:0.727001	validation_1-auc:0.710751
# [7]	validation_0-auc:0.727001	validation_1-auc:0.710751
# [8]	validation_0-auc:0.727001	validation_1-auc:0.710751
# [9]	validation_0-auc:0.727001	validation_1-auc:0.710751
# [10]	validation_0-auc:0.729048	validation_1-auc:0.714772
# [11]	validation_0-auc:0.729027	validation_1-auc:0.714679
# [12]	validation_0-auc:0.729027	validation_1-auc:0.714679
# [13]	validation_0-auc:0.729027	validation_1-auc:0.714679
# [14]	validation_0-auc:0.729027	validation_1-auc:0.714679
# [15]	validation_0-auc:0.729027	validation_1-auc:0.714679
# [16]	validation_0-auc:0.729027	validation_1-auc:0.714679
# [17]	validation_0-auc:0.729027	validation_1-auc:0.714679
# [18]	validation_0-auc:0.729027	validation_1-auc:0.714679
# [19]	validation_0-auc:0.729027	validation_1-auc:0.714679
# [20]	validation_0-auc:0.729027	validation_1-auc:0.714679
# Stopping. Best iteration:
# [10]	validation_0-auc:0.729048	validation_1-auc:0.714772
#
# [0]	validation_0-auc:0.739756	validation_1-auc:0.703698
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.802611	validation_1-auc:0.770937
# [2]	validation_0-auc:0.817683	validation_1-auc:0.780074
# [3]	validation_0-auc:0.833531	validation_1-auc:0.797085
# [4]	validation_0-auc:0.84656	validation_1-auc:0.812755
# [5]	validation_0-auc:0.861114	validation_1-auc:0.826676
# [6]	validation_0-auc:0.86915	validation_1-auc:0.833295
# [7]	validation_0-auc:0.878633	validation_1-auc:0.84383
# [8]	validation_0-auc:0.892678	validation_1-auc:0.851694
# [9]	validation_0-auc:0.896969	validation_1-auc:0.855713
# [10]	validation_0-auc:0.904611	validation_1-auc:0.86284
# [11]	validation_0-auc:0.911478	validation_1-auc:0.866225
# [12]	validation_0-auc:0.912406	validation_1-auc:0.865456
# [13]	validation_0-auc:0.914665	validation_1-auc:0.866205
# [14]	validation_0-auc:0.914665	validation_1-auc:0.866205
# [15]	validation_0-auc:0.914665	validation_1-auc:0.866205
# [16]	validation_0-auc:0.916626	validation_1-auc:0.870946
# [17]	validation_0-auc:0.916445	validation_1-auc:0.870787
# [18]	validation_0-auc:0.916445	validation_1-auc:0.870787
# ...
# [1]	validation_0-auc:0.918023	validation_1-auc:0.915135
# [2]	validation_0-auc:0.926033	validation_1-auc:0.933181
# [3]	validation_0-auc:0.950343	validation_1-auc:0.95395
# [4]	validation_0-auc:0.953755	validation_1-auc:0.959912
# [5]	validation_0-auc:0.9531	validation_1-auc:0.95907
# [6]	validation_0-auc:0.956956	validation_1-auc:0.961627
# [7]	validation_0-auc:0.959158	validation_1-auc:0.965085
# [8]	validation_0-auc:0.960161	validation_1-auc:0.965792
# [9]	validation_0-auc:0.961047	validation_1-auc:0.964378
# [10]	validation_0-auc:0.963052	validation_1-auc:0.965922
# [11]	validation_0-auc:0.964368	validation_1-auc:0.967418
# [12]	validation_0-auc:0.963856	validation_1-auc:0.966517
# [13]	validation_0-auc:0.966608	validation_1-auc:0.969339
# [14]	validation_0-auc:0.966613	validation_1-auc:0.970246
# [15]	validation_0-auc:0.966058	validation_1-auc:0.969587
# [16]	validation_0-auc:0.967183	validation_1-auc:0.97146
# [17]	validation_0-auc:0.967387	validation_1-auc:0.970836
# [18]	validation_0-auc:0.968898	validation_1-auc:0.971543
# [19]	validation_0-auc:0.970474	validation_1-auc:0.973051
# [20]	validation_0-auc:0.969707	validation_1-auc:0.97265
# [21]	validation_0-auc:0.971322	validation_1-auc:0.972385
# [22]	validation_0-auc:0.972179	validation_1-auc:0.973481
# [23]	validation_0-auc:0.972179	validation_1-auc:0.973481
# [24]	validation_0-auc:0.972179	validation_1-auc:0.973481
# [25]	validation_0-auc:0.972179	validation_1-auc:0.973481
# [26]	validation_0-auc:0.972179	validation_1-auc:0.973481
# [27]	validation_0-auc:0.972179	validation_1-auc:0.973481
# [28]	validation_0-auc:0.972179	validation_1-auc:0.973481
# [29]	validation_0-auc:0.972262	validation_1-auc:0.972697
# [30]	validation_0-auc:0.972262	validation_1-auc:0.972697
# [31]	validation_0-auc:0.971879	validation_1-auc:0.972874
# [32]	validation_0-auc:0.971879	validation_1-auc:0.972874
# Stopping. Best iteration:
# [22]	validation_0-auc:0.972179	validation_1-auc:0.973481
#
# [0]	validation_0-auc:0.857967	validation_1-auc:0.850166
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.890999	validation_1-auc:0.890979
# [2]	validation_0-auc:0.927052	validation_1-auc:0.927502
# [3]	validation_0-auc:0.933284	validation_1-auc:0.937347
# [4]	validation_0-auc:0.936002	validation_1-auc:0.943515
# [5]	validation_0-auc:0.95628	validation_1-auc:0.961438
# [6]	validation_0-auc:0.954837	validation_1-auc:0.960395
# [7]	validation_0-auc:0.95766	validation_1-auc:0.96049
# [8]	validation_0-auc:0.961907	validation_1-auc:0.962352
# [9]	validation_0-auc:0.963702	validation_1-auc:0.964396
# [10]	validation_0-auc:0.967286	validation_1-auc:0.966217
# [11]	validation_0-auc:0.968472	validation_1-auc:0.965804
# [12]	validation_0-auc:0.969372	validation_1-auc:0.963689
# [13]	validation_0-auc:0.970673	validation_1-auc:0.963766
# [14]	validation_0-auc:0.972207	validation_1-auc:0.964873
# [15]	validation_0-auc:0.97168	validation_1-auc:0.96515
# [16]	validation_0-auc:0.970752	validation_1-auc:0.965439
# [17]	validation_0-auc:0.972212	validation_1-auc:0.966876
# [18]	validation_0-auc:0.972641	validation_1-auc:0.966535
# [19]	validation_0-auc:0.974805	validation_1-auc:0.96822
# [20]	validation_0-auc:0.976315	validation_1-auc:0.968927
# [21]	validation_0-auc:0.977357	validation_1-auc:0.969139
# [22]	validation_0-auc:0.977944	validation_1-auc:0.970294
# [23]	validation_0-auc:0.978908	validation_1-auc:0.970305
# [24]	validation_0-auc:0.978613	validation_1-auc:0.970258
# [25]	validation_0-auc:0.980217	validation_1-auc:0.971413
# [26]	validation_0-auc:0.980618	validation_1-auc:0.971554
# [27]	validation_0-auc:0.981279	validation_1-auc:0.973287
# [28]	validation_0-auc:0.981279	validation_1-auc:0.973287
# [29]	validation_0-auc:0.981279	validation_1-auc:0.973287
# [30]	validation_0-auc:0.981279	validation_1-auc:0.973287
# [31]	validation_0-auc:0.981279	validation_1-auc:0.973287
# [32]	validation_0-auc:0.981279	validation_1-auc:0.973287
# [33]	validation_0-auc:0.981279	validation_1-auc:0.973287
# [34]	validation_0-auc:0.981279	validation_1-auc:0.973287
# [35]	validation_0-auc:0.981279	validation_1-auc:0.973287
# [36]	validation_0-auc:0.981279	validation_1-auc:0.973287
# [37]	validation_0-auc:0.981279	validation_1-auc:0.973287
# Stopping. Best iteration:
# [27]	validation_0-auc:0.981279	validation_1-auc:0.973287
#
# [0]	validation_0-auc:0.844984	validation_1-auc:0.842796
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.856593	validation_1-auc:0.84996
# [2]	validation_0-auc:0.89198	validation_1-auc:0.882247
# [3]	validation_0-auc:0.907084	validation_1-auc:0.892169
# [4]	validation_0-auc:0.911493	validation_1-auc:0.893565
# [5]	validation_0-auc:0.934171	validation_1-auc:0.934866
# [6]	validation_0-auc:0.940136	validation_1-auc:0.94077
# [7]	validation_0-auc:0.943672	validation_1-auc:0.94916
# [8]	validation_0-auc:0.944752	validation_1-auc:0.952789
# [9]	validation_0-auc:0.94852	validation_1-auc:0.958233
# [10]	validation_0-auc:0.950696	validation_1-auc:0.958139
# [11]	validation_0-auc:0.953019	validation_1-auc:0.959294
# [12]	validation_0-auc:0.954527	validation_1-auc:0.961662
# [13]	validation_0-auc:0.957382	validation_1-auc:0.961444
# [14]	validation_0-auc:0.960696	validation_1-auc:0.964744
# [15]	validation_0-auc:0.961685	validation_1-auc:0.965792
# [16]	validation_0-auc:0.961962	validation_1-auc:0.96495
# [17]	validation_0-auc:0.962537	validation_1-auc:0.964596
# [18]	validation_0-auc:0.962255	validation_1-auc:0.965244
# [19]	validation_0-auc:0.962255	validation_1-auc:0.965244
# [20]	validation_0-auc:0.962255	validation_1-auc:0.965244
# [21]	validation_0-auc:0.962255	validation_1-auc:0.965244
# [22]	validation_0-auc:0.962255	validation_1-auc:0.965244
# [23]	validation_0-auc:0.962255	validation_1-auc:0.965244
# [24]	validation_0-auc:0.962255	validation_1-auc:0.965244
# [25]	validation_0-auc:0.962936	validation_1-auc:0.964832
# Stopping. Best iteration:
# [15]	validation_0-auc:0.961685	validation_1-auc:0.965792
#
# [0]	validation_0-auc:0.896625	validation_1-auc:0.904188
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.928285	validation_1-auc:0.924797
# [2]	validation_0-auc:0.930058	validation_1-auc:0.929434
# [3]	validation_0-auc:0.952038	validation_1-auc:0.943492
# [4]	validation_0-auc:0.957137	validation_1-auc:0.953225
# [5]	validation_0-auc:0.961238	validation_1-auc:0.95818
# [6]	validation_0-auc:0.963344	validation_1-auc:0.960837
# [7]	validation_0-auc:0.969982	validation_1-auc:0.960366
# [8]	validation_0-auc:0.969009	validation_1-auc:0.959818
# [9]	validation_0-auc:0.970073	validation_1-auc:0.962375
# [10]	validation_0-auc:0.969902	validation_1-auc:0.96452
# [11]	validation_0-auc:0.970517	validation_1-auc:0.966299
# [12]	validation_0-auc:0.971276	validation_1-auc:0.965934
# [13]	validation_0-auc:0.973879	validation_1-auc:0.969416
# [14]	validation_0-auc:0.974782	validation_1-auc:0.970488
# [15]	validation_0-auc:0.97576	validation_1-auc:0.971849
# [16]	validation_0-auc:0.976956	validation_1-auc:0.972751
# [17]	validation_0-auc:0.978298	validation_1-auc:0.974117
# [18]	validation_0-auc:0.978852	validation_1-auc:0.974559
# [19]	validation_0-auc:0.980436	validation_1-auc:0.975361
# [20]	validation_0-auc:0.982308	validation_1-auc:0.976822
# [21]	validation_0-auc:0.982308	validation_1-auc:0.976822
# [22]	validation_0-auc:0.982504	validation_1-auc:0.976892
# [23]	validation_0-auc:0.982504	validation_1-auc:0.976892
# [24]	validation_0-auc:0.982504	validation_1-auc:0.976892
# [25]	validation_0-auc:0.982504	validation_1-auc:0.976892
# [26]	validation_0-auc:0.983281	validation_1-auc:0.977116
# [27]	validation_0-auc:0.983281	validation_1-auc:0.977116
# [28]	validation_0-auc:0.983281	validation_1-auc:0.977116
# [29]	validation_0-auc:0.983281	validation_1-auc:0.977116
# [30]	validation_0-auc:0.983281	validation_1-auc:0.977116
# [31]	validation_0-auc:0.983281	validation_1-auc:0.977116
# [32]	validation_0-auc:0.983004	validation_1-auc:0.97668
# [33]	validation_0-auc:0.983004	validation_1-auc:0.97668
# [34]	validation_0-auc:0.983004	validation_1-auc:0.97668
# [35]	validation_0-auc:0.983004	validation_1-auc:0.97668
# [36]	validation_0-auc:0.983004	validation_1-auc:0.97668
# Stopping. Best iteration:
# [26]	validation_0-auc:0.983281	validation_1-auc:0.977116
#
# [0]	validation_0-auc:0.5	validation_1-auc:0.5
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.5	validation_1-auc:0.5
# [2]	validation_0-auc:0.5	validation_1-auc:0.5
# [3]	validation_0-auc:0.5	validation_1-auc:0.5
# [4]	validation_0-auc:0.5	validation_1-auc:0.5
# [5]	validation_0-auc:0.5	validation_1-auc:0.5
# [6]	validation_0-auc:0.5	validation_1-auc:0.5
# [7]	validation_0-auc:0.5	validation_1-auc:0.5
# [8]	validation_0-auc:0.5	validation_1-auc:0.5
# [9]	validation_0-auc:0.5	validation_1-auc:0.5
# [10]	validation_0-auc:0.5	validation_1-auc:0.5
# Stopping. Best iteration:
# [0]	validation_0-auc:0.5	validation_1-auc:0.5
#
# [0]	validation_0-auc:0.5	validation_1-auc:0.5
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.5	validation_1-auc:0.5
# [2]	validation_0-auc:0.5	validation_1-auc:0.5
# [3]	validation_0-auc:0.5	validation_1-auc:0.5
# [4]	validation_0-auc:0.5	validation_1-auc:0.5
# [5]	validation_0-auc:0.5	validation_1-auc:0.5
# [6]	validation_0-auc:0.5	validation_1-auc:0.5
# [7]	validation_0-auc:0.5	validation_1-auc:0.5
# [8]	validation_0-auc:0.5	validation_1-auc:0.5
# [9]	validation_0-auc:0.5	validation_1-auc:0.5
# [10]	validation_0-auc:0.5	validation_1-auc:0.5
# Stopping. Best iteration:
# [0]	validation_0-auc:0.5	validation_1-auc:0.5
#
# [0]	validation_0-auc:0.5	validation_1-auc:0.5
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.5	validation_1-auc:0.5
# [2]	validation_0-auc:0.5	validation_1-auc:0.5
# [3]	validation_0-auc:0.5	validation_1-auc:0.5
# [4]	validation_0-auc:0.5	validation_1-auc:0.5
# [5]	validation_0-auc:0.5	validation_1-auc:0.5
# [6]	validation_0-auc:0.5	validation_1-auc:0.5
# [7]	validation_0-auc:0.5	validation_1-auc:0.5
# [8]	validation_0-auc:0.5	validation_1-auc:0.5
# [9]	validation_0-auc:0.5	validation_1-auc:0.5
# [10]	validation_0-auc:0.5	validation_1-auc:0.5
# Stopping. Best iteration:
# [0]	validation_0-auc:0.5	validation_1-auc:0.5
#
# [0]	validation_0-auc:0.5	validation_1-auc:0.5
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.5	validation_1-auc:0.5
# [2]	validation_0-auc:0.5	validation_1-auc:0.5
# [3]	validation_0-auc:0.5	validation_1-auc:0.5
# [4]	validation_0-auc:0.5	validation_1-auc:0.5
# [5]	validation_0-auc:0.5	validation_1-auc:0.5
# [6]	validation_0-auc:0.5	validation_1-auc:0.5
# [7]	validation_0-auc:0.5	validation_1-auc:0.5
# [8]	validation_0-auc:0.5	validation_1-auc:0.5
# [9]	validation_0-auc:0.5	validation_1-auc:0.5
# [10]	validation_0-auc:0.5	validation_1-auc:0.5
# Stopping. Best iteration:
# [0]	validation_0-auc:0.5	validation_1-auc:0.5
#
# [0]	validation_0-auc:0.881153	validation_1-auc:0.836362
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.896552	validation_1-auc:0.847403
# [2]	validation_0-auc:0.93089	validation_1-auc:0.925316
# [3]	validation_0-auc:0.944376	validation_1-auc:0.936775
# [4]	validation_0-auc:0.956	validation_1-auc:0.954993
# [5]	validation_0-auc:0.956623	validation_1-auc:0.955193
# [6]	validation_0-auc:0.959602	validation_1-auc:0.959683
# [7]	validation_0-auc:0.964565	validation_1-auc:0.959936
# [8]	validation_0-auc:0.96805	validation_1-auc:0.959576
# [9]	validation_0-auc:0.968282	validation_1-auc:0.962287
# [10]	validation_0-auc:0.969291	validation_1-auc:0.963654
# [11]	validation_0-auc:0.971654	validation_1-auc:0.962546
# [12]	validation_0-auc:0.97395	validation_1-auc:0.963889
# [13]	validation_0-auc:0.975654	validation_1-auc:0.966977
# [14]	validation_0-auc:0.97687	validation_1-auc:0.969416
# [15]	validation_0-auc:0.978189	validation_1-auc:0.971802
# [16]	validation_0-auc:0.977738	validation_1-auc:0.972415
# [17]	validation_0-auc:0.978613	validation_1-auc:0.972515
# [18]	validation_0-auc:0.979662	validation_1-auc:0.973952
# [19]	validation_0-auc:0.981564	validation_1-auc:0.974671
# [20]	validation_0-auc:0.982396	validation_1-auc:0.9744
# [21]	validation_0-auc:0.984219	validation_1-auc:0.975914
# [22]	validation_0-auc:0.985274	validation_1-auc:0.976869
# [23]	validation_0-auc:0.985844	validation_1-auc:0.97711
# [24]	validation_0-auc:0.98632	validation_1-auc:0.978083
# [25]	validation_0-auc:0.986573	validation_1-auc:0.977175
# [26]	validation_0-auc:0.986986	validation_1-auc:0.977317
# [27]	validation_0-auc:0.98739	validation_1-auc:0.977882
# [28]	validation_0-auc:0.988525	validation_1-auc:0.977759
# [29]	validation_0-auc:0.988878	validation_1-auc:0.978301
# [30]	validation_0-auc:0.988878	validation_1-auc:0.978301
# [31]	validation_0-auc:0.988878	validation_1-auc:0.978301
# [32]	validation_0-auc:0.988979	validation_1-auc:0.978784
# [33]	validation_0-auc:0.988979	validation_1-auc:0.978784
# [34]	validation_0-auc:0.988979	validation_1-auc:0.978784
# [35]	validation_0-auc:0.989322	validation_1-auc:0.97955
# [36]	validation_0-auc:0.989322	validation_1-auc:0.97955
# [37]	validation_0-auc:0.989322	validation_1-auc:0.97955
# [38]	validation_0-auc:0.989322	validation_1-auc:0.97955
# [0]	validation_0-auc:0.775533	validation_1-auc:0.757133
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.8067	validation_1-auc:0.785095
# [2]	validation_0-auc:0.840832	validation_1-auc:0.81169
# [3]	validation_0-auc:0.863653	validation_1-auc:0.836339
# [4]	validation_0-auc:0.878673	validation_1-auc:0.851476
# [5]	validation_0-auc:0.88242	validation_1-auc:0.855535
# [6]	validation_0-auc:0.888145	validation_1-auc:0.862167
# [7]	validation_0-auc:0.89349	validation_1-auc:0.866675
# [8]	validation_0-auc:0.900963	validation_1-auc:0.872321
# [9]	validation_0-auc:0.906758	validation_1-auc:0.878087
# [10]	validation_0-auc:0.907745	validation_1-auc:0.879939
# [11]	validation_0-auc:0.91314	validation_1-auc:0.884575
# [12]	validation_0-auc:0.915188	validation_1-auc:0.887394
# [13]	validation_0-auc:0.92128	validation_1-auc:0.893814
# [14]	validation_0-auc:0.928065	validation_1-auc:0.902087
# [15]	validation_0-auc:0.929359	validation_1-auc:0.904424
# [16]	validation_0-auc:0.929565	validation_1-auc:0.903979
# [17]	validation_0-auc:0.930262	validation_1-auc:0.905033
# [18]	validation_0-auc:0.933883	validation_1-auc:0.907892
# [19]	validation_0-auc:0.936802	validation_1-auc:0.909577
# [20]	validation_0-auc:0.94058	validation_1-auc:0.914958
# [21]	validation_0-auc:0.942753	validation_1-auc:0.916644
# [22]	validation_0-auc:0.944887	validation_1-auc:0.920035
# [23]	validation_0-auc:0.946942	validation_1-auc:0.921614
# [24]	validation_0-auc:0.948878	validation_1-auc:0.92258
# [25]	validation_0-auc:0.951451	validation_1-auc:0.926796
# [26]	validation_0-auc:0.953757	validation_1-auc:0.929707
# [27]	validation_0-auc:0.954588	validation_1-auc:0.929977
# [28]	validation_0-auc:0.956213	validation_1-auc:0.930626
# [29]	validation_0-auc:0.96	validation_1-auc:0.934861
# [30]	validation_0-auc:0.961238	validation_1-auc:0.936883
# [31]	validation_0-auc:0.962469	validation_1-auc:0.937618
# [32]	validation_0-auc:0.96381	validation_1-auc:0.93876
# [33]	validation_0-auc:0.965518	validation_1-auc:0.938469
# [34]	validation_0-auc:0.966713	validation_1-auc:0.939519
# [35]	validation_0-auc:0.966408	validation_1-auc:0.939325
# [36]	validation_0-auc:0.967323	validation_1-auc:0.941062
# [37]	validation_0-auc:0.968178	validation_1-auc:0.942337
# [38]	validation_0-auc:0.968948	validation_1-auc:0.943548

# %%
# Test
X=base_test.iloc[:, 7:].drop(["target_alza", "target_baja", "target"], 1)
preds_alza = model_alza.predict_proba(X)
preds_baja = model_baja.predict_proba(X)
oos = base_test.iloc[:, 0:4]
oos['pred_alza'] = preds_alza[:,1]
oos['pred_baja'] = preds_baja[:,1]
oos = oos.sort_values(["ticker", "fc"], ascending = (False, True))
oos['result'] = (oos.y.shift(-dias)/oos.y) - 1
oos['result'] = np.where(oos.ticker != oos.ticker.shift(-dias), np.nan, oos.result)
oos['result_pn'] = np.where(oos.result > 0, "Alza", "Baja")
oos['result_pn'] = np.where(oos.ticker != oos.ticker.shift(-dias), np.nan, oos.result_pn)
oos = oos.sort_values(["fc"], ascending = (True))

# %%
oos['bucket_alza'] = pd.qcut(oos['pred_alza'].values, 10, duplicates='drop')
oos['bucket_baja'] = pd.qcut(oos['pred_baja'].values, 10, duplicates='drop')

#print("Cantidad:")
#oos.groupby(['bucket_alza', 'bucket_baja']).agg({'result': ['count']}).unstack()
print("Promedios:")
oos.groupby(['bucket_alza', 'bucket_baja']).agg({'result': ['median']}).unstack()
#print("Máximos:")
#oos.groupby(['bucket_alza', 'bucket_baja']).max().unstack()
#print("Mínimos:")
#oos.groupby(['bucket_alza', 'bucket_baja']).min().unstack()
# Out:
# Promedios:
#                                           result
#                                           median
# bucket_baja      (0.0030299999999999997, 0.0151] (0.0151, 0.021] (0.021, 0.0283] (0.0283, 0.0362] (0.0362, 0.0532] (0.0532, 0.0785] (0.0785, 0.105] (0.105, 0.138] (0.138, 0.202] (0.202, 0.71]
# bucket_alza
# (0.0154, 0.0781]                       -0.002106       -0.027406       -0.018938        -0.154420        -0.177250        -0.146592       -0.175000      -0.104145       0.080817     -0.195892
# (0.0781, 0.12]                         -0.016088        0.002853       -0.031574         0.018257        -0.007788         0.183447       -0.031104      -0.027381       0.066852     -0.149711
# (0.12, 0.148]                           0.006337       -0.002630       -0.007178        -0.001817         0.059093         0.138627        0.051949       0.082096      -0.040082     -0.031418
# (0.148, 0.179]                          0.026450        0.057533        0.135254         0.204751         0.159389         0.015388        0.078327       0.084318      -0.043411     -0.150497
# (0.179, 0.216]                          0.225660        0.059163        0.225894         0.310949         0.057120         0.016515        0.058670      -0.006889       0.015373     -0.088639
# (0.216, 0.256]                          0.285029       -0.073037        0.257622         0.104363         0.056224         0.039088       -0.126528      -0.099356       0.209333     -0.106327
# (0.256, 0.326]                          0.279587        0.123875        0.092372        -0.178011        -0.106924        -0.012963        0.086008      -0.149106      -0.061456     -0.106596
# (0.326, 0.425]                          0.331968        0.342992       -0.053239         0.060294         0.017042         0.014622       -0.151387      -0.319634       0.070003     -0.017299
# (0.425, 0.577]                          0.342325        0.289071        0.250798         0.095568         0.295402        -0.239239       -0.165391      -0.222001      -0.134677     -0.291532
# (0.577, 0.906]                         -0.089963        0.127851        0.073093        -0.254244         0.086645        -0.264306       -0.369829       0.026383      -0.476720     -0.303346
