# %%
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import date, timedelta
import sys
import json
sys.path.insert(1, 'C:/Users/ffliguer/Documents/algotrading/shared_code')
from iol_algotrading import *
pd.options.mode.chained_assignment = None
#actual = pd.read_csv(r'C:\Users\ffliguer\Desktop\Proyectos\Señales S&P\soportes y resistencias\soportes_resistencias_global_500_5l.csv')
#tickers = actual.ticker.unique()

# Todos los tickers del SP500 en todos los períodos
url = 'https://raw.githubusercontent.com/fja05680/sp500/master/S%26P%20500%20Historical%20Components%20%26%20Changes(01-15-2022).csv'
resp = requests.get(url)
df = pd.DataFrame([x.split('"') for x in resp.text.split('\n')])
df = df.iloc[1:-1, 0:-1].reset_index(drop=True)
df.columns = ['Date', 'SP500']
df['Date'] = df['Date'].replace(',','', regex=True)
df['Date'] = pd.to_datetime(df['Date'])
lista = df[df.Date > '2017-01-01'].SP500.values
i = 0
tickers = list()
while i < len(lista):
    tickers.extend((lista[i].split(",")))
    i = i + 1
list(set(tickers))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-f3684f710e67> in <module>
#      17 df = pd.DataFrame([x.split('"') for x in resp.text.split('\n')])
#      18 df = df.iloc[1:-1, 0:-1].reset_index(drop=True)
# ---> 19 df.columns = ['Date', 'SP500']
#      20 df['Date'] = df['Date'].replace(',','', regex=True)
#      21 df['Date'] = pd.to_datetime(df['Date'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
# ...

# %%
empieza = '2003-08-01'
termina = '2021-08-31'

estaba = 0
noestaba_listado = 0
noestaba_deslistado = 0

for ticker in df[df.Date == '2017-01-06'].SP500.values[0].split(","):
    if ticker in tickers:
        print('estaba')
        estaba = estaba + 1
    else:
        base = yf.download(ticker, start=empieza, end=termina).reset_index()
        if len(base) == 0:
            print('noestaba_deslistado')
            noestaba_deslistado = noestaba_deslistado + 1
        else:
            print('noestaba_listado')
            noestaba_listado = noestaba_listado + 1
# Out:
# estaba
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AABA: No data found, symbol may be delisted
# noestaba_deslistado
# estaba
# estaba
# estaba
# estaba
# estaba
# estaba
# estaba
# estaba
# estaba
# estaba
# estaba
# [*********************100%***********************]  1 of 1 completed
# noestaba_listado
# estaba
# estaba
# estaba
# estaba
# [*********************100%***********************]  1 of 1 completed
# noestaba_listado
# estaba
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AGN: No data found, symbol may be delisted
# noestaba_deslistado
# estaba
# [*********************100%***********************]  1 of 1 completed
# noestaba_listado
# estaba
# estaba
# estaba
# estaba
# estaba
# estaba
# estaba
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALXN: No data found, symbol may be delisted
# noestaba_deslistado
# estaba
# ...
